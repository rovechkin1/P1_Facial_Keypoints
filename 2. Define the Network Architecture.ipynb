# %% [markdown]
# ## Define the Convolutional Neural Network
#
# After you've looked at the data you're working with and, in this case, know the shapes of the images and of the keypoints, you are ready to define a convolutional neural network that can *learn* from this data.
#
# In this notebook and in `models.py`, you will:
# 1. Define a CNN with images as input and keypoints as output
# 2. Construct the transformed FaceKeypointsDataset, just as before
# 3. Train the CNN on the training data, tracking loss
# 4. See how the trained model performs on test data
# 5. If necessary, modify the CNN structure and model hyperparameters, so that it performs *well* **\***
#
# **\*** What does *well* mean?
#
# "Well" means that the model's loss decreases during training **and**, when applied to test image data, the model produces keypoints that closely match the true keypoints of each face. And you'll see examples of this later in the notebook.
#
# ---

# %% [markdown]
# ## CNN Architecture
#
# Recall that CNN's are defined by a few types of layers:
# * Convolutional layers
# * Maxpooling layers
# * Fully-connected layers
#
# You are required to use the above layers and encouraged to add multiple convolutional layers and things like dropout layers that may prevent overfitting. You are also encouraged to look at literature on keypoint detection, such as [this paper](https://arxiv.org/pdf/1710.00977.pdf), to help you determine the structure of your network.
#
#
# ### TODO: Define your model in the provided file `models.py` file
#
# This file is mostly empty but contains the expected name and some TODO's for creating your model.
#
# ---

# %% [markdown]
# ## PyTorch Neural Nets
#
# To define a neural network in PyTorch, you define the layers of a model in the function `__init__` and define the feedforward behavior of a network that employs those initialized layers in the function `forward`, which takes in an input image tensor, `x`. The structure of this Net class is shown below and left for you to fill in.
#
# Note: During training, PyTorch will be able to perform backpropagation by keeping track of the network's feedforward behavior and using autograd to calculate the update to the weights in the network.
#
# #### Define the Layers in ` __init__`
# As a reminder, a conv/pool layer may be defined like this (in `__init__`):
# ```
# # 1 input image channel (for grayscale images), 32 output channels/feature maps, 3x3 square convolution kernel
# self.conv1 = nn.Conv2d(1, 32, 3)
#
# # maxpool that uses a square window of kernel_size=2, stride=2
# self.pool = nn.MaxPool2d(2, 2)
# ```
#
# #### Refer to Layers in `forward`
# Then referred to in the `forward` function like this, in which the conv1 layer has a ReLu activation applied to it before maxpooling is applied:
# ```
# x = self.pool(F.relu(self.conv1(x)))
# ```
#
# Best practice is to place any layers whose weights will change during the training process in `__init__` and refer to them in the `forward` function; any layers or functions that always behave in the same way, such as a pre-defined activation function, should appear *only* in the `forward` function.

# %% [markdown]
# #### Why models.py
#
# You are tasked with defining the network in the `models.py` file so that any models you define can be saved and loaded by name in different notebooks in this project directory. For example, by defining a CNN class called `Net` in `models.py`, you can then create that same architecture in this and other notebooks by simply importing the class and instantiating a model:
# ```
#     from models import Net
#     net = Net()
# ```

# %%
# import the usual resources
import matplotlib.pyplot as plt
import numpy as np

# watch for any changes in model.py, if it changes, re-load it automatically
# %load_ext autoreload
# %autoreload 2

# %%
## TODO: Define the Net in models.py

import torch
import torch.nn as nn
import torch.nn.functional as F

batch_size = 600
print('cuda: ',torch.cuda.is_available())
torch.cuda.empty_cache()
#dtype = torch.FloatTensor
dtype = torch.cuda.FloatTensor # Uncomment this to run on GPU

model_dir = 'saved_models/'
model_name = 'keypoints_model_4.pt'

## TODO: Once you've define the network, you can instantiate it
# one example conv layer has been provided for you
from models import Net

net = Net().cuda()  if type(dtype) is type(torch.cuda.FloatTensor) else Net()   
print(net)
# Out:
# cuda:  True
# Net(
#   (c1): Conv2d(1, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#   (pool): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (rl): ReLU(inplace=True)
#   (c2): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (c3): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (c4): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (c5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (drop): Dropout(p=0.5, inplace=False)
#   (fc1): Linear(in_features=9216, out_features=4096, bias=True)
#   (fc2): Linear(in_features=4096, out_features=4096, bias=True)
#   (fc3): Linear(in_features=4096, out_features=136, bias=True)
# )

# %% [markdown]
# ## Transform the dataset
#
# To prepare for training, create a transformed dataset of images and keypoints.
#
# ### TODO: Define a data transform
#
# In PyTorch, a convolutional neural network expects a torch image of a consistent size as input. For efficient training, and so your model's loss does not blow up during training, it is also suggested that you normalize the input images and keypoints. The necessary transforms have been defined in `data_load.py` and you **do not** need to modify these; take a look at this file (you'll see the same transforms that were defined and applied in Notebook 1).
#
# To define the data transform below, use a [composition](http://pytorch.org/tutorials/beginner/data_loading_tutorial.html#compose-transforms) of:
# 1. Rescaling and/or cropping the data, such that you are left with a square image (the suggested size is 224x224px)
# 2. Normalizing the images and keypoints; turning each RGB image into a grayscale image with a color range of [0, 1] and transforming the given keypoints into a range of [-1, 1]
# 3. Turning these images and keypoints into Tensors
#
# These transformations have been defined in `data_load.py`, but it's up to you to call them and create a `data_transform` below. **This transform will be applied to the training data and, later, the test data**. It will change how you go about displaying these images and keypoints, but these steps are essential for efficient training.
#
# As a note, should you want to perform data augmentation (which is optional in this project), and randomly rotate or shift these images, a square image size will be useful; rotating a 224x224 image by 90 degrees will result in the same shape of output.

# %%
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils

# the dataset we created in Notebook 1 is copied in the helper file `data_load.py`
from data_load import FacialKeypointsDataset
# the transforms we defined in Notebook 1 are in the helper file `data_load.py`
from data_load import Rescale, RandomCrop, Normalize, ToTensor


## TODO: define the data_transform using transforms.Compose([all tx's, . , .])
# order matters! i.e. rescaling should come before a smaller crop
data_transform = transforms.Compose([Rescale(250),
                                     RandomCrop(224),
                                     Normalize(),
                                     ToTensor()])

# testing that you've defined a transform
assert(data_transform is not None), 'Define a data_transform'

# %%
# create the transformed dataset
transformed_dataset = FacialKeypointsDataset(csv_file='data/training_frames_keypoints.csv',
                                             root_dir='data/training/',
                                             transform=data_transform)


print('Number of images: ', len(transformed_dataset))

# iterate through the transformed dataset and print some stats about the first few samples
for i in range(4):
    sample = transformed_dataset[i]
    print(i, sample['image'].size(), sample['keypoints'].size())
# Out:
# Number of images:  3462
# 0 torch.Size([1, 224, 224]) torch.Size([68, 2])
# 1 torch.Size([1, 224, 224]) torch.Size([68, 2])
# 2 torch.Size([1, 224, 224]) torch.Size([68, 2])
# 3 torch.Size([1, 224, 224]) torch.Size([68, 2])
# /home/jupyter/P1_Facial_Keypoints/data_load.py:39: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   key_pts = self.key_pts_frame.iloc[idx, 1:].as_matrix()

# %% [markdown]
# ## Batching and loading data
#
# Next, having defined the transformed dataset, we can use PyTorch's DataLoader class to load the training data in batches of whatever size as well as to shuffle the data for training the model. You can read more about the parameters of the DataLoader, in [this documentation](http://pytorch.org/docs/master/data.html).
#
# #### Batch size
# Decide on a good batch size for training your model. Try both small and large batch sizes and note how the loss decreases as the model trains.
#
# **Note for Windows users**: Please change the `num_workers` to 0 or you may face some issues with your DataLoader failing.

# %%
# load training data in batches


train_loader = DataLoader(transformed_dataset, 
                          batch_size=batch_size,
                          shuffle=True, 
                          num_workers=4)

# %% [markdown]
# ## Before training
#
# Take a look at how this model performs before it trains. You should see that the keypoints it predicts start off in one spot and don't match the keypoints on a face at all! It's interesting to visualize this behavior so that you can compare it to the model after training and see how the model has improved.
#
# #### Load in the test dataset
#
# The test dataset is one that this model has *not* seen before, meaning it has not trained with these images. We'll load in this test data and before and after training, see how your model performs on this set!
#
# To visualize this test data, we have to go through some un-transformation steps to turn our images into python images from tensors and to turn our keypoints back into a recognizable range.

# %%
# load in the test data, using the dataset class
# AND apply the data_transform you defined above

# create the test dataset
test_dataset = FacialKeypointsDataset(csv_file='data/test_frames_keypoints.csv',
                                             root_dir='data/test/',
                                             transform=data_transform)

# %%
# load test data in batches


test_loader = DataLoader(test_dataset, 
                          batch_size=batch_size,
                          shuffle=True, 
                          num_workers=4)

# %% [markdown]
# ## Apply the model on a test sample
#
# To test the model on a test sample of data, you have to follow these steps:
# 1. Extract the image and ground truth keypoints from a sample
# 2. Make sure the image is a FloatTensor, which the model expects.
# 3. Forward pass the image through the net to get the predicted, output keypoints.
#
# This function test how the network performs on the first batch of test data. It returns the images, the transformed images, the predicted keypoints (produced by the model), and the ground truth keypoints.

# %%
# test the model on a batch of test images

def net_sample_output():
    
    # iterate through the test dataset
    for i, sample in enumerate(test_loader):
        
        # get sample data: images and ground truth keypoints
        images = sample['image']
        key_pts = sample['keypoints']

        # convert images to FloatTensors
        images = images.type(dtype)

        # forward pass to get net output
        output_pts = net(images)
        
        # reshape to batch_size x 68 x 2 pts
        output_pts = output_pts.view(output_pts.size()[0], 68, -1)
        
        # break after first image is tested
        if i == 0:
            return images, output_pts, key_pts

# %% [markdown]
# #### Debugging tips
#
# If you get a size or dimension error here, make sure that your network outputs the expected number of keypoints! Or if you get a Tensor type error, look into changing the above code that casts the data into float types: `images = images.type(torch.FloatTensor)`.

# %%
# call the above function
# returns: test images, test predicted keypoints, test ground truth keypoints
test_images, test_outputs, gt_pts = net_sample_output()

# print out the dimensions of the data to see if they make sense
print(test_images.data.size())
print(test_outputs.data.size())
print(gt_pts.size())
# Out:
# torch.Size([600, 1, 224, 224])
# torch.Size([600, 68, 2])
# torch.Size([600, 68, 2])

# %% [markdown]
# ## Visualize the predicted keypoints
#
# Once we've had the model produce some predicted output keypoints, we can visualize these points in a way that's similar to how we've displayed this data before, only this time, we have to "un-transform" the image/keypoint data to display it.
#
# Note that I've defined a *new* function, `show_all_keypoints` that displays a grayscale image, its predicted keypoints and its ground truth keypoints (if provided).

# %%
def show_all_keypoints(image, predicted_key_pts, gt_pts=None):
    """Show image with predicted keypoints"""
    # image is grayscale
    plt.imshow(image, cmap='gray')
    plt.scatter(predicted_key_pts[:, 0], predicted_key_pts[:, 1], s=20, marker='.', c='m')
    # plot ground truth points as green pts
    if gt_pts is not None:
        plt.scatter(gt_pts[:, 0], gt_pts[:, 1], s=20, marker='.', c='g')

# %% [markdown]
# #### Un-transformation
#
# Next, you'll see a helper function. `visualize_output` that takes in a batch of images, predicted keypoints, and ground truth keypoints and displays a set of those images and their true/predicted keypoints.
#
# This function's main role is to take batches of image and keypoint data (the input and output of your CNN), and transform them into numpy images and un-normalized keypoints (x, y) for normal display. The un-transformation process turns keypoints and images into numpy arrays from Tensors *and* it undoes the keypoint normalization done in the Normalize() transform; it's assumed that you applied these transformations when you loaded your test data.

# %%
# visualize the output
# by default this shows a batch of 10 images
def visualize_output(test_images, test_outputs, gt_pts=None, batch_size=10):

    for i in range(batch_size):
        plt.figure(figsize=(20,10))
        ax = plt.subplot(1, batch_size, i+1)

        # un-transform the image data
        image = test_images[i].data.cpu()   # get the image from it's wrapper
        image = image.numpy()   # convert to numpy array from a Tensor
        image = np.transpose(image, (1, 2, 0))   # transpose to go from torch to numpy image

        # un-transform the predicted key_pts data
        predicted_key_pts = test_outputs[i].data.cpu()
        predicted_key_pts = predicted_key_pts.numpy()
        # undo normalization of keypoints  
        predicted_key_pts = predicted_key_pts*50.0+100
        
        # plot ground truth points for comparison, if they exist
        ground_truth_pts = None
        if gt_pts is not None:
            ground_truth_pts = gt_pts[i]         
            ground_truth_pts = ground_truth_pts*50.0+100
        
        # call show_all_keypoints
        show_all_keypoints(np.squeeze(image), predicted_key_pts, ground_truth_pts)
            
        plt.axis('off')

    plt.show()
    
# call it
visualize_output(test_images, test_outputs, gt_pts)

# %% [markdown]
# ## Training
#
# #### Loss function
# Training a network to predict keypoints is different than training a network to predict a class; instead of outputting a distribution of classes and using cross entropy loss, you may want to choose a loss function that is suited for regression, which directly compares a predicted value and target value. Read about the various kinds of loss functions (like MSE or L1/SmoothL1 loss) in [this documentation](http://pytorch.org/docs/master/_modules/torch/nn/modules/loss.html).
#
# ### TODO: Define the loss and optimization
#
# Next, you'll define how the model will train by deciding on the loss function and optimizer.
#
# ---

# %%
## TODO: Define the loss and optimization
import torch.optim as optim

criterion = nn.L1Loss()

optimizer = optim.Adam(net.parameters(), lr=0.0005)

# %% [markdown]
# ## Training and Initial Observation
#
# Now, you'll train on your batched training data from `train_loader` for a number of epochs.
#
# To quickly observe how your model is training and decide on whether or not you should modify it's structure or hyperparameters, you're encouraged to start off with just one or two epochs at first. As you train, note how your the model's loss behaves over time: does it decrease quickly at first and then slow down? Does it take a while to decrease in the first place? What happens if you change the batch size of your training data or modify your loss function? etc.
#
# Use these initial observations to make changes to your model and decide on the best architecture before you train for many epochs and create a final model.

# %%
def train_net(n_epochs):

    # prepare the net for training
    net.train()

    for epoch in range(n_epochs):  # loop over the dataset multiple times
        
        running_loss = 0.0

        # train on batches of data, assumes you already have train_loader
        for batch_i, data in enumerate(train_loader):
            # get the input images and their corresponding labels
            images = data['image']
            key_pts = data['keypoints']

            # flatten pts
            key_pts = key_pts.view(key_pts.size(0), -1)

            # convert variables to floats for regression loss
            key_pts = key_pts.type(dtype)
            images = images.type(dtype)

            # forward pass to get outputs
            output_pts = net(images)

            # calculate the loss between predicted and target keypoints
            loss = criterion(output_pts, key_pts)

            # zero the parameter (weight) gradients
            optimizer.zero_grad()
            
            # backward pass to calculate the weight gradients
            loss.backward()

            # update the weights
            optimizer.step()

            # print loss statistics
            # to convert loss into a scalar and add it to the running_loss, use .item()
            running_loss += loss.item()
            if batch_i % 2 == 1:    # print every 10 batches
                print('Epoch: {}, Batch: {}, Avg. Loss: {}'.format(epoch + 1, batch_i+1, running_loss/1000))
                running_loss = 0.0

    print('Finished Training')

# %%
## TODO: change the name to something uniqe for each new model


# after training, save your model parameters in the dir 'saved_models'
#net.load_state_dict(torch.load(model_dir+model_name))
#net.eval()

# %%
# train your network
n_epochs = 500 # start small, and increase when you've decided on your model structure and hyperparams

train_net(n_epochs)
# Out:
# Epoch: 1, Batch: 2, Avg. Loss: 8.496778458356858e-05
# Epoch: 1, Batch: 4, Avg. Loss: 8.374245464801788e-05
# Epoch: 1, Batch: 6, Avg. Loss: 8.467289060354232e-05
# Epoch: 2, Batch: 2, Avg. Loss: 8.327066898345947e-05
# Epoch: 2, Batch: 4, Avg. Loss: 8.606087788939476e-05
# Epoch: 2, Batch: 6, Avg. Loss: 8.449171856045723e-05
# Epoch: 3, Batch: 2, Avg. Loss: 8.375979959964752e-05
# Epoch: 3, Batch: 4, Avg. Loss: 8.35699923336506e-05
# Epoch: 3, Batch: 6, Avg. Loss: 8.387775346636772e-05
# Epoch: 4, Batch: 2, Avg. Loss: 8.27021449804306e-05
# Epoch: 4, Batch: 4, Avg. Loss: 8.49379189312458e-05
# Epoch: 4, Batch: 6, Avg. Loss: 8.641212806105614e-05
# Epoch: 5, Batch: 2, Avg. Loss: 8.383489027619362e-05
# Epoch: 5, Batch: 4, Avg. Loss: 8.415160700678826e-05
# Epoch: 5, Batch: 6, Avg. Loss: 8.55129361152649e-05
# Epoch: 6, Batch: 2, Avg. Loss: 8.376576751470566e-05
# Epoch: 6, Batch: 4, Avg. Loss: 8.440298959612847e-05
# Epoch: 6, Batch: 6, Avg. Loss: 8.371204882860183e-05
# Epoch: 7, Batch: 2, Avg. Loss: 8.420982584357261e-05
# Epoch: 7, Batch: 4, Avg. Loss: 8.370549231767655e-05
# Epoch: 7, Batch: 6, Avg. Loss: 8.318304643034934e-05
# Epoch: 8, Batch: 2, Avg. Loss: 8.299115672707558e-05
# Epoch: 8, Batch: 4, Avg. Loss: 8.382000774145126e-05
# Epoch: 8, Batch: 6, Avg. Loss: 8.408061414957047e-05
# Epoch: 9, Batch: 2, Avg. Loss: 8.285000175237656e-05
# Epoch: 9, Batch: 4, Avg. Loss: 8.350759372115136e-05
# Epoch: 9, Batch: 6, Avg. Loss: 8.341962099075317e-05
# Epoch: 10, Batch: 2, Avg. Loss: 8.352906256914139e-05
# Epoch: 10, Batch: 4, Avg. Loss: 8.203384280204773e-05
# Epoch: 10, Batch: 6, Avg. Loss: 8.326144516468048e-05
# Epoch: 11, Batch: 2, Avg. Loss: 8.245269954204559e-05
# Epoch: 11, Batch: 4, Avg. Loss: 8.518814668059349e-05
# Epoch: 11, Batch: 6, Avg. Loss: 8.19951668381691e-05
# Epoch: 12, Batch: 2, Avg. Loss: 8.238013461232185e-05
# Epoch: 12, Batch: 4, Avg. Loss: 8.286688104271889e-05
# Epoch: 12, Batch: 6, Avg. Loss: 8.383755758404732e-05
# Epoch: 13, Batch: 2, Avg. Loss: 8.216707780957222e-05
# Epoch: 13, Batch: 4, Avg. Loss: 8.326369151473045e-05
# Epoch: 13, Batch: 6, Avg. Loss: 8.228232339024543e-05
# Epoch: 14, Batch: 2, Avg. Loss: 8.278246968984604e-05
# Epoch: 14, Batch: 4, Avg. Loss: 8.305193483829498e-05
# Epoch: 14, Batch: 6, Avg. Loss: 8.295831829309464e-05
# Epoch: 15, Batch: 2, Avg. Loss: 8.215907216072082e-05
# Epoch: 15, Batch: 4, Avg. Loss: 8.258727565407753e-05
# Epoch: 15, Batch: 6, Avg. Loss: 8.357012644410134e-05
# Epoch: 16, Batch: 2, Avg. Loss: 8.466070890426636e-05
# Epoch: 16, Batch: 4, Avg. Loss: 8.19627232849598e-05
# Epoch: 16, Batch: 6, Avg. Loss: 8.216824382543563e-05
# Epoch: 17, Batch: 2, Avg. Loss: 8.11513476073742e-05
# Epoch: 17, Batch: 4, Avg. Loss: 8.329695835709572e-05
# Epoch: 17, Batch: 6, Avg. Loss: 8.438941836357117e-05
# Epoch: 18, Batch: 2, Avg. Loss: 8.407960459589958e-05
# Epoch: 18, Batch: 4, Avg. Loss: 8.413831517100334e-05
# Epoch: 18, Batch: 6, Avg. Loss: 8.464160189032555e-05
# Epoch: 19, Batch: 2, Avg. Loss: 8.549578115344047e-05
# Epoch: 19, Batch: 4, Avg. Loss: 8.309786394238472e-05
# Epoch: 19, Batch: 6, Avg. Loss: 8.527376130223274e-05
# Epoch: 20, Batch: 2, Avg. Loss: 8.376014232635498e-05
# Epoch: 20, Batch: 4, Avg. Loss: 8.31470713019371e-05
# Epoch: 20, Batch: 6, Avg. Loss: 8.281441032886505e-05
# Epoch: 21, Batch: 2, Avg. Loss: 8.244937658309936e-05
# Epoch: 21, Batch: 4, Avg. Loss: 8.365552127361298e-05
# Epoch: 21, Batch: 6, Avg. Loss: 8.451579883694649e-05
# Epoch: 22, Batch: 2, Avg. Loss: 8.13274346292019e-05
# Epoch: 22, Batch: 4, Avg. Loss: 8.294862508773803e-05
# Epoch: 22, Batch: 6, Avg. Loss: 8.20789709687233e-05
# Epoch: 23, Batch: 2, Avg. Loss: 8.222359046339988e-05
# Epoch: 23, Batch: 4, Avg. Loss: 8.317752182483673e-05
# Epoch: 23, Batch: 6, Avg. Loss: 8.354479819536209e-05
# Epoch: 24, Batch: 2, Avg. Loss: 8.362290263175964e-05
# Epoch: 24, Batch: 4, Avg. Loss: 8.089850842952728e-05
# Epoch: 24, Batch: 6, Avg. Loss: 8.234575763344765e-05
# Epoch: 25, Batch: 2, Avg. Loss: 8.219039440155029e-05
# Epoch: 25, Batch: 4, Avg. Loss: 8.300718665122986e-05
# Epoch: 25, Batch: 6, Avg. Loss: 8.274586871266365e-05
# Epoch: 26, Batch: 2, Avg. Loss: 8.491627499461174e-05
# Epoch: 26, Batch: 4, Avg. Loss: 8.492422476410865e-05
# Epoch: 26, Batch: 6, Avg. Loss: 8.539799228310584e-05
# Epoch: 27, Batch: 2, Avg. Loss: 8.171150833368301e-05
# Epoch: 27, Batch: 4, Avg. Loss: 8.225176855921746e-05
# Epoch: 27, Batch: 6, Avg. Loss: 8.309527114033699e-05
# Epoch: 28, Batch: 2, Avg. Loss: 8.450856432318688e-05
# Epoch: 28, Batch: 4, Avg. Loss: 8.216472715139389e-05
# Epoch: 28, Batch: 6, Avg. Loss: 8.428329229354858e-05
# Epoch: 29, Batch: 2, Avg. Loss: 8.36338847875595e-05
# Epoch: 29, Batch: 4, Avg. Loss: 8.361817523837089e-05
# Epoch: 29, Batch: 6, Avg. Loss: 8.329564332962036e-05
# Epoch: 30, Batch: 2, Avg. Loss: 8.469223231077195e-05
# Epoch: 30, Batch: 4, Avg. Loss: 8.230571076273918e-05
# Epoch: 30, Batch: 6, Avg. Loss: 8.169761300086975e-05
# Epoch: 31, Batch: 2, Avg. Loss: 8.231417834758759e-05
# Epoch: 31, Batch: 4, Avg. Loss: 8.377152308821678e-05
# Epoch: 31, Batch: 6, Avg. Loss: 8.260265737771988e-05
# Epoch: 32, Batch: 2, Avg. Loss: 8.402307331562043e-05
# Epoch: 32, Batch: 4, Avg. Loss: 8.178778365254403e-05
# Epoch: 32, Batch: 6, Avg. Loss: 8.233113214373589e-05
# Epoch: 33, Batch: 2, Avg. Loss: 8.333465456962585e-05
# Epoch: 33, Batch: 4, Avg. Loss: 8.277468755841255e-05
# Epoch: 33, Batch: 6, Avg. Loss: 8.34115482866764e-05
# Epoch: 34, Batch: 2, Avg. Loss: 8.348326757550239e-05
# Epoch: 34, Batch: 4, Avg. Loss: 8.288853242993355e-05
# Epoch: 34, Batch: 6, Avg. Loss: 8.433456718921661e-05
# Epoch: 35, Batch: 2, Avg. Loss: 8.227882906794548e-05
# Epoch: 35, Batch: 4, Avg. Loss: 8.461540564894677e-05
# Epoch: 35, Batch: 6, Avg. Loss: 8.38928185403347e-05
# Epoch: 36, Batch: 2, Avg. Loss: 8.188707381486893e-05
# Epoch: 36, Batch: 4, Avg. Loss: 8.380860462784767e-05
# Epoch: 36, Batch: 6, Avg. Loss: 8.363845199346543e-05
# Epoch: 37, Batch: 2, Avg. Loss: 8.19808654487133e-05
# Epoch: 37, Batch: 4, Avg. Loss: 8.188362419605255e-05
# Epoch: 37, Batch: 6, Avg. Loss: 8.224144205451012e-05
# Epoch: 38, Batch: 2, Avg. Loss: 8.292189240455627e-05
# Epoch: 38, Batch: 4, Avg. Loss: 8.218361064791679e-05
# Epoch: 38, Batch: 6, Avg. Loss: 8.037661761045456e-05
# Epoch: 39, Batch: 2, Avg. Loss: 8.259043470025063e-05
# Epoch: 39, Batch: 4, Avg. Loss: 8.257031440734863e-05
# Epoch: 39, Batch: 6, Avg. Loss: 8.209602162241936e-05
# Epoch: 40, Batch: 2, Avg. Loss: 8.108307421207428e-05
# Epoch: 40, Batch: 4, Avg. Loss: 8.156761899590492e-05
# Epoch: 40, Batch: 6, Avg. Loss: 8.503106236457824e-05
# Epoch: 41, Batch: 2, Avg. Loss: 8.247372508049011e-05
# Epoch: 41, Batch: 4, Avg. Loss: 8.104755729436875e-05
# Epoch: 41, Batch: 6, Avg. Loss: 8.228137344121933e-05
# Epoch: 42, Batch: 2, Avg. Loss: 8.110851794481277e-05
# Epoch: 42, Batch: 4, Avg. Loss: 8.338123187422752e-05
# Epoch: 42, Batch: 6, Avg. Loss: 8.206493780016899e-05
# Epoch: 43, Batch: 2, Avg. Loss: 8.352585136890411e-05
# Epoch: 43, Batch: 4, Avg. Loss: 8.061900734901428e-05
# Epoch: 43, Batch: 6, Avg. Loss: 8.477668464183807e-05
# Epoch: 44, Batch: 2, Avg. Loss: 8.304267376661301e-05
# Epoch: 44, Batch: 4, Avg. Loss: 8.120942488312722e-05
# Epoch: 44, Batch: 6, Avg. Loss: 8.391331881284714e-05
# Epoch: 45, Batch: 2, Avg. Loss: 8.2655418664217e-05
# Epoch: 45, Batch: 4, Avg. Loss: 8.354201540350914e-05
# Epoch: 45, Batch: 6, Avg. Loss: 8.257092535495758e-05
# Epoch: 46, Batch: 2, Avg. Loss: 8.077533915638924e-05
# Epoch: 46, Batch: 4, Avg. Loss: 8.390073850750923e-05
# Epoch: 46, Batch: 6, Avg. Loss: 8.469965681433678e-05
# Epoch: 47, Batch: 2, Avg. Loss: 8.130213990807533e-05
# Epoch: 47, Batch: 4, Avg. Loss: 8.104395493865013e-05
# Epoch: 47, Batch: 6, Avg. Loss: 8.44467468559742e-05
# Epoch: 48, Batch: 2, Avg. Loss: 8.233857527375222e-05
# Epoch: 48, Batch: 4, Avg. Loss: 8.304422348737716e-05
# Epoch: 48, Batch: 6, Avg. Loss: 8.285154029726983e-05
# Epoch: 49, Batch: 2, Avg. Loss: 8.357569947838783e-05
# Epoch: 49, Batch: 4, Avg. Loss: 8.189870417118072e-05
# Epoch: 49, Batch: 6, Avg. Loss: 8.272919803857804e-05
# Epoch: 50, Batch: 2, Avg. Loss: 8.07943232357502e-05
# Epoch: 50, Batch: 4, Avg. Loss: 8.177055045962334e-05
# Epoch: 50, Batch: 6, Avg. Loss: 7.984541356563568e-05
# Epoch: 51, Batch: 2, Avg. Loss: 8.234095573425293e-05
# Epoch: 51, Batch: 4, Avg. Loss: 8.232463151216506e-05
# Epoch: 51, Batch: 6, Avg. Loss: 8.180929720401764e-05
# Epoch: 52, Batch: 2, Avg. Loss: 8.314922824501992e-05
# Epoch: 52, Batch: 4, Avg. Loss: 8.394498005509377e-05
# Epoch: 52, Batch: 6, Avg. Loss: 8.402468264102936e-05
# Epoch: 53, Batch: 2, Avg. Loss: 8.060792088508606e-05
# Epoch: 53, Batch: 4, Avg. Loss: 8.157066628336906e-05
# Epoch: 53, Batch: 6, Avg. Loss: 8.34241546690464e-05
# Epoch: 54, Batch: 2, Avg. Loss: 8.321289345622063e-05
# Epoch: 54, Batch: 4, Avg. Loss: 8.160013705492019e-05
# Epoch: 54, Batch: 6, Avg. Loss: 8.32691304385662e-05
# Epoch: 55, Batch: 2, Avg. Loss: 8.373860642313957e-05
# Epoch: 55, Batch: 4, Avg. Loss: 7.989465817809105e-05
# Epoch: 55, Batch: 6, Avg. Loss: 8.225058764219283e-05
# Epoch: 56, Batch: 2, Avg. Loss: 8.115341141819954e-05
# Epoch: 56, Batch: 4, Avg. Loss: 8.069559931755066e-05
# Epoch: 56, Batch: 6, Avg. Loss: 8.261288702487945e-05
# Epoch: 57, Batch: 2, Avg. Loss: 8.010663092136383e-05
# Epoch: 57, Batch: 4, Avg. Loss: 8.244932070374489e-05
# Epoch: 57, Batch: 6, Avg. Loss: 8.28627310693264e-05
# Epoch: 58, Batch: 2, Avg. Loss: 8.260436728596687e-05
# Epoch: 58, Batch: 4, Avg. Loss: 7.925351336598397e-05
# Epoch: 58, Batch: 6, Avg. Loss: 8.231200277805328e-05
# Epoch: 59, Batch: 2, Avg. Loss: 8.280261233448982e-05
# Epoch: 59, Batch: 4, Avg. Loss: 8.178037032485008e-05
# Epoch: 59, Batch: 6, Avg. Loss: 8.160152658820152e-05
# Epoch: 60, Batch: 2, Avg. Loss: 8.141790330410004e-05
# Epoch: 60, Batch: 4, Avg. Loss: 8.140396699309349e-05
# Epoch: 60, Batch: 6, Avg. Loss: 8.199268952012062e-05
# Epoch: 61, Batch: 2, Avg. Loss: 8.089226856827736e-05
# Epoch: 61, Batch: 4, Avg. Loss: 8.392646163702011e-05
# Epoch: 61, Batch: 6, Avg. Loss: 8.253585547208786e-05
# Epoch: 62, Batch: 2, Avg. Loss: 8.332416415214539e-05
# Epoch: 62, Batch: 4, Avg. Loss: 8.210992068052292e-05
# Epoch: 62, Batch: 6, Avg. Loss: 8.181148394942283e-05
# Epoch: 63, Batch: 2, Avg. Loss: 8.175208792090416e-05
# Epoch: 63, Batch: 4, Avg. Loss: 8.24449397623539e-05
# Epoch: 63, Batch: 6, Avg. Loss: 8.130959048867226e-05
# Epoch: 64, Batch: 2, Avg. Loss: 8.246155828237533e-05
# Epoch: 64, Batch: 4, Avg. Loss: 8.282607048749924e-05
# Epoch: 64, Batch: 6, Avg. Loss: 8.204389736056328e-05
# Epoch: 65, Batch: 2, Avg. Loss: 8.082487434148788e-05
# Epoch: 65, Batch: 4, Avg. Loss: 8.258651196956635e-05
# Epoch: 65, Batch: 6, Avg. Loss: 8.167766779661179e-05
# Epoch: 66, Batch: 2, Avg. Loss: 8.123921230435372e-05
# Epoch: 66, Batch: 4, Avg. Loss: 8.091895282268524e-05
# Epoch: 66, Batch: 6, Avg. Loss: 8.019755780696868e-05
# Epoch: 67, Batch: 2, Avg. Loss: 8.05152952671051e-05
# Epoch: 67, Batch: 4, Avg. Loss: 8.032359927892685e-05
# Epoch: 67, Batch: 6, Avg. Loss: 8.188796043395997e-05
# Epoch: 68, Batch: 2, Avg. Loss: 8.124976605176925e-05
# Epoch: 68, Batch: 4, Avg. Loss: 8.245162293314933e-05
# Epoch: 68, Batch: 6, Avg. Loss: 8.253703638911247e-05
# Epoch: 69, Batch: 2, Avg. Loss: 7.995046675205231e-05
# Epoch: 69, Batch: 4, Avg. Loss: 8.171600103378296e-05
# Epoch: 69, Batch: 6, Avg. Loss: 8.314187824726104e-05
# Epoch: 70, Batch: 2, Avg. Loss: 8.140324056148529e-05
# Epoch: 70, Batch: 4, Avg. Loss: 8.155686780810357e-05
# Epoch: 70, Batch: 6, Avg. Loss: 8.219712227582931e-05
# Epoch: 71, Batch: 2, Avg. Loss: 8.074431866407394e-05
# Epoch: 71, Batch: 4, Avg. Loss: 8.15986879169941e-05
# Epoch: 71, Batch: 6, Avg. Loss: 8.202641829848289e-05
# Epoch: 72, Batch: 2, Avg. Loss: 8.085831254720688e-05
# Epoch: 72, Batch: 4, Avg. Loss: 8.20755660533905e-05
# Epoch: 72, Batch: 6, Avg. Loss: 7.983562350273132e-05
# Epoch: 73, Batch: 2, Avg. Loss: 8.076699823141098e-05
# Epoch: 73, Batch: 4, Avg. Loss: 7.933352887630463e-05
# Epoch: 73, Batch: 6, Avg. Loss: 8.09122733771801e-05
# Epoch: 74, Batch: 2, Avg. Loss: 8.013474941253663e-05
# Epoch: 74, Batch: 4, Avg. Loss: 8.0653365701437e-05
# Epoch: 74, Batch: 6, Avg. Loss: 8.080180734395981e-05
# Epoch: 75, Batch: 2, Avg. Loss: 8.015377074480057e-05
# Epoch: 75, Batch: 4, Avg. Loss: 8.17367248237133e-05
# Epoch: 75, Batch: 6, Avg. Loss: 8.039959892630577e-05
# Epoch: 76, Batch: 2, Avg. Loss: 8.234824985265731e-05
# Epoch: 76, Batch: 4, Avg. Loss: 7.915746048092843e-05
# Epoch: 76, Batch: 6, Avg. Loss: 8.252720907330513e-05
# Epoch: 77, Batch: 2, Avg. Loss: 8.092650398612023e-05
# Epoch: 77, Batch: 4, Avg. Loss: 8.12375321984291e-05
# Epoch: 77, Batch: 6, Avg. Loss: 8.079999685287475e-05
# Epoch: 78, Batch: 2, Avg. Loss: 8.207163214683533e-05
# Epoch: 78, Batch: 4, Avg. Loss: 8.065984398126602e-05
# Epoch: 78, Batch: 6, Avg. Loss: 7.98826515674591e-05
# Epoch: 79, Batch: 2, Avg. Loss: 8.149154484272004e-05
# Epoch: 79, Batch: 4, Avg. Loss: 7.998810708522797e-05
# Epoch: 79, Batch: 6, Avg. Loss: 8.083928748965264e-05
# Epoch: 80, Batch: 2, Avg. Loss: 8.194606378674507e-05
# Epoch: 80, Batch: 4, Avg. Loss: 8.028880879282952e-05
# Epoch: 80, Batch: 6, Avg. Loss: 8.108187839388847e-05
# Epoch: 81, Batch: 2, Avg. Loss: 8.288500830531121e-05
# Epoch: 81, Batch: 4, Avg. Loss: 8.300104737281799e-05
# Epoch: 81, Batch: 6, Avg. Loss: 8.08836966753006e-05
# Epoch: 82, Batch: 2, Avg. Loss: 8.169199153780937e-05
# Epoch: 82, Batch: 4, Avg. Loss: 8.064573258161544e-05
# Epoch: 82, Batch: 6, Avg. Loss: 8.080773800611496e-05
# Epoch: 83, Batch: 2, Avg. Loss: 8.073082566261291e-05
# Epoch: 83, Batch: 4, Avg. Loss: 8.147834241390228e-05
# Epoch: 83, Batch: 6, Avg. Loss: 8.069271966814995e-05
# Epoch: 84, Batch: 2, Avg. Loss: 8.382228761911392e-05
# Epoch: 84, Batch: 4, Avg. Loss: 8.117032423615455e-05
# Epoch: 84, Batch: 6, Avg. Loss: 7.951539382338524e-05
# Epoch: 85, Batch: 2, Avg. Loss: 7.903946191072464e-05
# Epoch: 85, Batch: 4, Avg. Loss: 8.035345375537872e-05
# Epoch: 85, Batch: 6, Avg. Loss: 8.041783794760704e-05
# Epoch: 86, Batch: 2, Avg. Loss: 8.12545344233513e-05
# Epoch: 86, Batch: 4, Avg. Loss: 8.205468207597732e-05
# Epoch: 86, Batch: 6, Avg. Loss: 8.055571839213371e-05
# Epoch: 87, Batch: 2, Avg. Loss: 8.147598803043366e-05
# Epoch: 87, Batch: 4, Avg. Loss: 8.206258714199067e-05
# Epoch: 87, Batch: 6, Avg. Loss: 8.228074386715889e-05
# Epoch: 88, Batch: 2, Avg. Loss: 7.989480718970298e-05
# Epoch: 88, Batch: 4, Avg. Loss: 8.267974480986595e-05
# Epoch: 88, Batch: 6, Avg. Loss: 7.984602451324463e-05
# Epoch: 89, Batch: 2, Avg. Loss: 7.994630932807922e-05
# Epoch: 89, Batch: 4, Avg. Loss: 8.094879239797593e-05
# Epoch: 89, Batch: 6, Avg. Loss: 8.058656379580498e-05
# Epoch: 90, Batch: 2, Avg. Loss: 7.931660115718841e-05
# Epoch: 90, Batch: 4, Avg. Loss: 7.965245097875596e-05
# Epoch: 90, Batch: 6, Avg. Loss: 8.091192692518235e-05
# Epoch: 91, Batch: 2, Avg. Loss: 8.15032608807087e-05
# Epoch: 91, Batch: 4, Avg. Loss: 8.084668591618537e-05
# Epoch: 91, Batch: 6, Avg. Loss: 7.840176671743392e-05
# Epoch: 92, Batch: 2, Avg. Loss: 8.17742682993412e-05
# Epoch: 92, Batch: 4, Avg. Loss: 8.156368881464004e-05
# Epoch: 92, Batch: 6, Avg. Loss: 8.198851719498634e-05
# Epoch: 93, Batch: 2, Avg. Loss: 7.983727380633354e-05
# Epoch: 93, Batch: 4, Avg. Loss: 8.101130649447441e-05
# Epoch: 93, Batch: 6, Avg. Loss: 8.030638098716736e-05
# Epoch: 94, Batch: 2, Avg. Loss: 7.892522960901261e-05
# Epoch: 94, Batch: 4, Avg. Loss: 8.137144893407822e-05
# Epoch: 94, Batch: 6, Avg. Loss: 8.074303716421128e-05
# Epoch: 95, Batch: 2, Avg. Loss: 8.075711131095886e-05
# Epoch: 95, Batch: 4, Avg. Loss: 8.105223253369332e-05
# Epoch: 95, Batch: 6, Avg. Loss: 8.063539117574692e-05
# Epoch: 96, Batch: 2, Avg. Loss: 8.054155111312866e-05
# Epoch: 96, Batch: 4, Avg. Loss: 8.100192248821259e-05
# Epoch: 96, Batch: 6, Avg. Loss: 8.044281974434853e-05
# Epoch: 97, Batch: 2, Avg. Loss: 8.051004260778427e-05
# Epoch: 97, Batch: 4, Avg. Loss: 8.112439140677452e-05
# Epoch: 97, Batch: 6, Avg. Loss: 7.967011630535126e-05
# Epoch: 98, Batch: 2, Avg. Loss: 7.97283686697483e-05
# Epoch: 98, Batch: 4, Avg. Loss: 7.900239899754524e-05
# Epoch: 98, Batch: 6, Avg. Loss: 7.978349551558495e-05
# Epoch: 99, Batch: 2, Avg. Loss: 7.911091297864914e-05
# Epoch: 99, Batch: 4, Avg. Loss: 7.990755513310433e-05
# Epoch: 99, Batch: 6, Avg. Loss: 8.0557681620121e-05
# Epoch: 100, Batch: 2, Avg. Loss: 8.066977560520172e-05
# Epoch: 100, Batch: 4, Avg. Loss: 8.233966305851936e-05
# Epoch: 100, Batch: 6, Avg. Loss: 7.992656901478767e-05
# Epoch: 101, Batch: 2, Avg. Loss: 8.251673728227616e-05
# Epoch: 101, Batch: 4, Avg. Loss: 8.058668300509453e-05
# Epoch: 101, Batch: 6, Avg. Loss: 7.916807755827904e-05
# Epoch: 102, Batch: 2, Avg. Loss: 7.969547435641289e-05
# Epoch: 102, Batch: 4, Avg. Loss: 7.809910178184509e-05
# Epoch: 102, Batch: 6, Avg. Loss: 8.110382035374641e-05
# Epoch: 103, Batch: 2, Avg. Loss: 7.987537607550622e-05
# Epoch: 103, Batch: 4, Avg. Loss: 7.98388049006462e-05
# Epoch: 103, Batch: 6, Avg. Loss: 8.030110597610474e-05
# Epoch: 104, Batch: 2, Avg. Loss: 7.951822504401206e-05
# Epoch: 104, Batch: 4, Avg. Loss: 8.125608041882515e-05
# Epoch: 104, Batch: 6, Avg. Loss: 8.108071610331535e-05
# Epoch: 105, Batch: 2, Avg. Loss: 7.991518080234527e-05
# Epoch: 105, Batch: 4, Avg. Loss: 7.891318202018738e-05
# Epoch: 105, Batch: 6, Avg. Loss: 8.089229464530945e-05
# Epoch: 106, Batch: 2, Avg. Loss: 7.8388512134552e-05
# Epoch: 106, Batch: 4, Avg. Loss: 8.131935074925422e-05
# Epoch: 106, Batch: 6, Avg. Loss: 7.902471348643303e-05
# Epoch: 107, Batch: 2, Avg. Loss: 7.851704582571983e-05
# Epoch: 107, Batch: 4, Avg. Loss: 7.971740141510963e-05
# Epoch: 107, Batch: 6, Avg. Loss: 8.086615800857544e-05
# Epoch: 108, Batch: 2, Avg. Loss: 8.004865422844887e-05
# Epoch: 108, Batch: 4, Avg. Loss: 7.809504866600036e-05
# Epoch: 108, Batch: 6, Avg. Loss: 7.961232215166092e-05
# Epoch: 109, Batch: 2, Avg. Loss: 8.013991266489029e-05
# Epoch: 109, Batch: 4, Avg. Loss: 8.111182972788811e-05
# Epoch: 109, Batch: 6, Avg. Loss: 8.00006277859211e-05
# Epoch: 110, Batch: 2, Avg. Loss: 8.174839988350869e-05
# Epoch: 110, Batch: 4, Avg. Loss: 8.147569373250008e-05
# Epoch: 110, Batch: 6, Avg. Loss: 8.000199496746063e-05
# Epoch: 111, Batch: 2, Avg. Loss: 8.044732734560967e-05
# Epoch: 111, Batch: 4, Avg. Loss: 8.05935263633728e-05
# Epoch: 111, Batch: 6, Avg. Loss: 8.025511726737022e-05
# Epoch: 112, Batch: 2, Avg. Loss: 8.158749714493751e-05
# Epoch: 112, Batch: 4, Avg. Loss: 8.058394119143486e-05
# Epoch: 112, Batch: 6, Avg. Loss: 8.042067661881446e-05
# Epoch: 113, Batch: 2, Avg. Loss: 8.237249776721001e-05
# Epoch: 113, Batch: 4, Avg. Loss: 8.057705685496331e-05
# Epoch: 113, Batch: 6, Avg. Loss: 8.160839974880218e-05
# Epoch: 114, Batch: 2, Avg. Loss: 8.021821454167366e-05
# Epoch: 114, Batch: 4, Avg. Loss: 7.980833947658538e-05
# Epoch: 114, Batch: 6, Avg. Loss: 8.165594190359115e-05
# Epoch: 115, Batch: 2, Avg. Loss: 7.979535311460494e-05
# Epoch: 115, Batch: 4, Avg. Loss: 7.86673091351986e-05
# Epoch: 115, Batch: 6, Avg. Loss: 8.001576364040374e-05
# Epoch: 116, Batch: 2, Avg. Loss: 8.033403009176254e-05
# Epoch: 116, Batch: 4, Avg. Loss: 8.244571089744567e-05
# Epoch: 116, Batch: 6, Avg. Loss: 7.981626316905021e-05
# Epoch: 117, Batch: 2, Avg. Loss: 8.223743736743927e-05
# Epoch: 117, Batch: 4, Avg. Loss: 8.198524639010429e-05
# Epoch: 117, Batch: 6, Avg. Loss: 8.039538189768792e-05
# Epoch: 118, Batch: 2, Avg. Loss: 8.151204511523247e-05
# Epoch: 118, Batch: 4, Avg. Loss: 7.992352545261383e-05
# Epoch: 118, Batch: 6, Avg. Loss: 7.928492501378059e-05
# Epoch: 119, Batch: 2, Avg. Loss: 7.880203053355216e-05
# Epoch: 119, Batch: 4, Avg. Loss: 8.076750487089157e-05
# Epoch: 119, Batch: 6, Avg. Loss: 8.049584552645683e-05
# Epoch: 120, Batch: 2, Avg. Loss: 7.856009900569915e-05
# Epoch: 120, Batch: 4, Avg. Loss: 7.996248453855514e-05
# Epoch: 120, Batch: 6, Avg. Loss: 8.158237114548683e-05
# Epoch: 121, Batch: 2, Avg. Loss: 7.79634416103363e-05
# Epoch: 121, Batch: 4, Avg. Loss: 7.988331839442253e-05
# Epoch: 121, Batch: 6, Avg. Loss: 8.047596365213394e-05
# Epoch: 122, Batch: 2, Avg. Loss: 8.003924414515495e-05
# Epoch: 122, Batch: 4, Avg. Loss: 7.98308216035366e-05
# Epoch: 122, Batch: 6, Avg. Loss: 7.916085794568061e-05
# Epoch: 123, Batch: 2, Avg. Loss: 7.802304625511169e-05
# Epoch: 123, Batch: 4, Avg. Loss: 8.105254545807839e-05
# Epoch: 123, Batch: 6, Avg. Loss: 7.842856273055077e-05
# Epoch: 124, Batch: 2, Avg. Loss: 7.825025171041489e-05
# Epoch: 124, Batch: 4, Avg. Loss: 7.942533865571022e-05
# Epoch: 124, Batch: 6, Avg. Loss: 7.973466813564301e-05
# Epoch: 125, Batch: 2, Avg. Loss: 7.824704423546791e-05
# Epoch: 125, Batch: 4, Avg. Loss: 8.188921958208085e-05
# Epoch: 125, Batch: 6, Avg. Loss: 7.863156124949455e-05
# Epoch: 126, Batch: 2, Avg. Loss: 7.895191386342048e-05
# Epoch: 126, Batch: 4, Avg. Loss: 7.95484222471714e-05
# Epoch: 126, Batch: 6, Avg. Loss: 7.994840666651726e-05
# Epoch: 127, Batch: 2, Avg. Loss: 7.898236066102982e-05
# Epoch: 127, Batch: 4, Avg. Loss: 7.812980562448502e-05
# Epoch: 127, Batch: 6, Avg. Loss: 7.963847741484642e-05
# Epoch: 128, Batch: 2, Avg. Loss: 7.777959853410721e-05
# Epoch: 128, Batch: 4, Avg. Loss: 8.00330638885498e-05
# Epoch: 128, Batch: 6, Avg. Loss: 7.876037433743477e-05
# Epoch: 129, Batch: 2, Avg. Loss: 7.83301182091236e-05
# Epoch: 129, Batch: 4, Avg. Loss: 8.069328963756561e-05
# Epoch: 129, Batch: 6, Avg. Loss: 7.998735457658767e-05
# Epoch: 130, Batch: 2, Avg. Loss: 8.043427392840385e-05
# Epoch: 130, Batch: 4, Avg. Loss: 8.095035329461098e-05
# Epoch: 130, Batch: 6, Avg. Loss: 7.974361628293991e-05
# Epoch: 131, Batch: 2, Avg. Loss: 7.935598120093345e-05
# Epoch: 131, Batch: 4, Avg. Loss: 8.015847206115723e-05
# Epoch: 131, Batch: 6, Avg. Loss: 8.158362656831741e-05
# Epoch: 132, Batch: 2, Avg. Loss: 7.96269066631794e-05
# Epoch: 132, Batch: 4, Avg. Loss: 8.051402494311333e-05
# Epoch: 132, Batch: 6, Avg. Loss: 8.031639084219932e-05
# Epoch: 133, Batch: 2, Avg. Loss: 7.916472107172012e-05
# Epoch: 133, Batch: 4, Avg. Loss: 8.129661530256271e-05
# Epoch: 133, Batch: 6, Avg. Loss: 8.005257695913315e-05
# Epoch: 134, Batch: 2, Avg. Loss: 7.841880619525909e-05
# Epoch: 134, Batch: 4, Avg. Loss: 7.979103550314903e-05
# Epoch: 134, Batch: 6, Avg. Loss: 7.99533911049366e-05
# Epoch: 135, Batch: 2, Avg. Loss: 7.950231805443764e-05
# Epoch: 135, Batch: 4, Avg. Loss: 7.79869444668293e-05
# Epoch: 135, Batch: 6, Avg. Loss: 7.852999866008759e-05
# Epoch: 136, Batch: 2, Avg. Loss: 7.736597582697869e-05
# Epoch: 136, Batch: 4, Avg. Loss: 8.000418543815612e-05
# Epoch: 136, Batch: 6, Avg. Loss: 7.980701699852943e-05
# Epoch: 137, Batch: 2, Avg. Loss: 8.046674728393555e-05
# Epoch: 137, Batch: 4, Avg. Loss: 8.210419118404388e-05
# Epoch: 137, Batch: 6, Avg. Loss: 7.973911985754967e-05
# Epoch: 138, Batch: 2, Avg. Loss: 7.90342576801777e-05
# Epoch: 138, Batch: 4, Avg. Loss: 7.956232875585555e-05
# Epoch: 138, Batch: 6, Avg. Loss: 7.855243235826493e-05
# Epoch: 139, Batch: 2, Avg. Loss: 7.939281314611435e-05
# Epoch: 139, Batch: 4, Avg. Loss: 7.875554263591766e-05
# Epoch: 139, Batch: 6, Avg. Loss: 7.930169627070426e-05
# Epoch: 140, Batch: 2, Avg. Loss: 7.912144809961319e-05
# Epoch: 140, Batch: 4, Avg. Loss: 7.914437353610992e-05
# Epoch: 140, Batch: 6, Avg. Loss: 7.859690487384796e-05
# Epoch: 141, Batch: 2, Avg. Loss: 7.910031825304032e-05
# Epoch: 141, Batch: 4, Avg. Loss: 7.78195895254612e-05
# Epoch: 141, Batch: 6, Avg. Loss: 7.826674357056618e-05
# Epoch: 142, Batch: 2, Avg. Loss: 7.830469310283661e-05
# Epoch: 142, Batch: 4, Avg. Loss: 7.846866175532341e-05
# Epoch: 142, Batch: 6, Avg. Loss: 7.953714579343796e-05
# Epoch: 143, Batch: 2, Avg. Loss: 7.824699953198433e-05
# Epoch: 143, Batch: 4, Avg. Loss: 7.716117054224015e-05
# Epoch: 143, Batch: 6, Avg. Loss: 7.799474522471428e-05
# Epoch: 144, Batch: 2, Avg. Loss: 7.77338594198227e-05
# Epoch: 144, Batch: 4, Avg. Loss: 7.885478436946868e-05
# Epoch: 144, Batch: 6, Avg. Loss: 7.769323140382766e-05
# Epoch: 145, Batch: 2, Avg. Loss: 7.85638689994812e-05
# Epoch: 145, Batch: 4, Avg. Loss: 7.727969437837601e-05
# Epoch: 145, Batch: 6, Avg. Loss: 7.731422036886215e-05
# Epoch: 146, Batch: 2, Avg. Loss: 7.861689478158951e-05
# Epoch: 146, Batch: 4, Avg. Loss: 7.812387123703957e-05
# Epoch: 146, Batch: 6, Avg. Loss: 7.772959768772126e-05
# Epoch: 147, Batch: 2, Avg. Loss: 7.838861644268036e-05
# Epoch: 147, Batch: 4, Avg. Loss: 7.899833098053933e-05
# Epoch: 147, Batch: 6, Avg. Loss: 7.788419723510743e-05
# Epoch: 148, Batch: 2, Avg. Loss: 7.897214218974113e-05
# Epoch: 148, Batch: 4, Avg. Loss: 7.866648212075233e-05
# Epoch: 148, Batch: 6, Avg. Loss: 7.92350172996521e-05
# Epoch: 149, Batch: 2, Avg. Loss: 7.785076647996902e-05
# Epoch: 149, Batch: 4, Avg. Loss: 7.861583679914474e-05
# Epoch: 149, Batch: 6, Avg. Loss: 7.786299288272857e-05
# Epoch: 150, Batch: 2, Avg. Loss: 7.788487523794175e-05
# Epoch: 150, Batch: 4, Avg. Loss: 7.792668417096138e-05
# Epoch: 150, Batch: 6, Avg. Loss: 7.841432467103005e-05
# Epoch: 151, Batch: 2, Avg. Loss: 7.829763740301133e-05
# Epoch: 151, Batch: 4, Avg. Loss: 7.865922898054123e-05
# Epoch: 151, Batch: 6, Avg. Loss: 7.81509056687355e-05
# Epoch: 152, Batch: 2, Avg. Loss: 7.89087861776352e-05
# Epoch: 152, Batch: 4, Avg. Loss: 7.83294141292572e-05
# Epoch: 152, Batch: 6, Avg. Loss: 7.788186147809029e-05
# Epoch: 153, Batch: 2, Avg. Loss: 7.725391164422035e-05
# Epoch: 153, Batch: 4, Avg. Loss: 7.815562933683395e-05
# Epoch: 153, Batch: 6, Avg. Loss: 7.897062227129936e-05
# Epoch: 154, Batch: 2, Avg. Loss: 7.851731404662132e-05
# Epoch: 154, Batch: 4, Avg. Loss: 7.846904173493385e-05
# Epoch: 154, Batch: 6, Avg. Loss: 8.299892023205757e-05
# Epoch: 155, Batch: 2, Avg. Loss: 7.814094051718712e-05
# Epoch: 155, Batch: 4, Avg. Loss: 7.930860668420791e-05
# Epoch: 155, Batch: 6, Avg. Loss: 7.720723748207092e-05
# Epoch: 156, Batch: 2, Avg. Loss: 7.789484784007073e-05
# Epoch: 156, Batch: 4, Avg. Loss: 7.816855236887932e-05
# Epoch: 156, Batch: 6, Avg. Loss: 8.179108798503876e-05
# Epoch: 157, Batch: 2, Avg. Loss: 7.838637009263039e-05
# Epoch: 157, Batch: 4, Avg. Loss: 7.919669523835183e-05
# Epoch: 157, Batch: 6, Avg. Loss: 7.909126952290536e-05
# Epoch: 158, Batch: 2, Avg. Loss: 7.941241934895516e-05
# Epoch: 158, Batch: 4, Avg. Loss: 7.973318919539452e-05
# Epoch: 158, Batch: 6, Avg. Loss: 7.906995713710785e-05
# Epoch: 159, Batch: 2, Avg. Loss: 7.901543378829957e-05
# Epoch: 159, Batch: 4, Avg. Loss: 7.716796547174453e-05
# Epoch: 159, Batch: 6, Avg. Loss: 7.861688360571862e-05
# Epoch: 160, Batch: 2, Avg. Loss: 7.660602778196335e-05
# Epoch: 160, Batch: 4, Avg. Loss: 7.848839834332466e-05
# Epoch: 160, Batch: 6, Avg. Loss: 7.637728378176689e-05
# Epoch: 161, Batch: 2, Avg. Loss: 7.887668162584304e-05
# Epoch: 161, Batch: 4, Avg. Loss: 7.966234907507897e-05
# Epoch: 161, Batch: 6, Avg. Loss: 7.836198806762695e-05
# Epoch: 162, Batch: 2, Avg. Loss: 7.738287746906281e-05
# Epoch: 162, Batch: 4, Avg. Loss: 8.073790371418e-05
# Epoch: 162, Batch: 6, Avg. Loss: 7.930947095155715e-05
# Epoch: 163, Batch: 2, Avg. Loss: 8.022935688495635e-05
# Epoch: 163, Batch: 4, Avg. Loss: 7.719937711954117e-05
# Epoch: 163, Batch: 6, Avg. Loss: 7.752951979637145e-05
# Epoch: 164, Batch: 2, Avg. Loss: 7.733813673257827e-05
# Epoch: 164, Batch: 4, Avg. Loss: 7.764001190662383e-05
# Epoch: 164, Batch: 6, Avg. Loss: 7.855793833732605e-05
# Epoch: 165, Batch: 2, Avg. Loss: 7.628997042775154e-05
# Epoch: 165, Batch: 4, Avg. Loss: 7.748666405677796e-05
# Epoch: 165, Batch: 6, Avg. Loss: 8.055691048502921e-05
# Epoch: 166, Batch: 2, Avg. Loss: 7.912121713161468e-05
# Epoch: 166, Batch: 4, Avg. Loss: 7.894066721200942e-05
# Epoch: 166, Batch: 6, Avg. Loss: 7.841173186898232e-05
# Epoch: 167, Batch: 2, Avg. Loss: 7.80828557908535e-05
# Epoch: 167, Batch: 4, Avg. Loss: 7.829656824469567e-05
# Epoch: 167, Batch: 6, Avg. Loss: 7.769781723618507e-05
# Epoch: 168, Batch: 2, Avg. Loss: 7.789701968431473e-05
# Epoch: 168, Batch: 4, Avg. Loss: 7.685066014528274e-05
# Epoch: 168, Batch: 6, Avg. Loss: 7.615531608462334e-05
# Epoch: 169, Batch: 2, Avg. Loss: 7.94241614639759e-05
# Epoch: 169, Batch: 4, Avg. Loss: 7.682289183139801e-05
# Epoch: 169, Batch: 6, Avg. Loss: 7.712467014789581e-05
# Epoch: 170, Batch: 2, Avg. Loss: 7.999682426452637e-05
# Epoch: 170, Batch: 4, Avg. Loss: 7.976970449090004e-05
# Epoch: 170, Batch: 6, Avg. Loss: 7.9995546489954e-05
# Epoch: 171, Batch: 2, Avg. Loss: 7.939820736646653e-05
# Epoch: 171, Batch: 4, Avg. Loss: 7.795701548457146e-05
# Epoch: 171, Batch: 6, Avg. Loss: 7.817692682147026e-05
# Epoch: 172, Batch: 2, Avg. Loss: 7.815098762512207e-05
# Epoch: 172, Batch: 4, Avg. Loss: 7.744382321834565e-05
# Epoch: 172, Batch: 6, Avg. Loss: 7.849711924791336e-05
# Epoch: 173, Batch: 2, Avg. Loss: 7.812319323420525e-05
# Epoch: 173, Batch: 4, Avg. Loss: 7.7731192111969e-05
# Epoch: 173, Batch: 6, Avg. Loss: 7.718198746442795e-05
# Epoch: 174, Batch: 2, Avg. Loss: 7.670243084430694e-05
# Epoch: 174, Batch: 4, Avg. Loss: 7.649338990449906e-05
# Epoch: 174, Batch: 6, Avg. Loss: 7.720604166388512e-05
# Epoch: 175, Batch: 2, Avg. Loss: 7.703542336821556e-05
# Epoch: 175, Batch: 4, Avg. Loss: 7.794351875782013e-05
# Epoch: 175, Batch: 6, Avg. Loss: 7.647257298231125e-05
# Epoch: 176, Batch: 2, Avg. Loss: 7.733185961842537e-05
# Epoch: 176, Batch: 4, Avg. Loss: 8.019563183188438e-05
# Epoch: 176, Batch: 6, Avg. Loss: 7.797488570213317e-05
# Epoch: 177, Batch: 2, Avg. Loss: 7.68585205078125e-05
# Epoch: 177, Batch: 4, Avg. Loss: 7.744104787707328e-05
# Epoch: 177, Batch: 6, Avg. Loss: 7.639114558696747e-05
# Epoch: 178, Batch: 2, Avg. Loss: 7.801819220185279e-05
# Epoch: 178, Batch: 4, Avg. Loss: 7.706392183899879e-05
# Epoch: 178, Batch: 6, Avg. Loss: 7.800081744790078e-05
# Epoch: 179, Batch: 2, Avg. Loss: 7.871554791927338e-05
# Epoch: 179, Batch: 4, Avg. Loss: 7.840541750192643e-05
# Epoch: 179, Batch: 6, Avg. Loss: 7.767167314887046e-05
# Epoch: 180, Batch: 2, Avg. Loss: 7.740407064557075e-05
# Epoch: 180, Batch: 4, Avg. Loss: 7.778321579098702e-05
# Epoch: 180, Batch: 6, Avg. Loss: 7.801670581102371e-05
# Epoch: 181, Batch: 2, Avg. Loss: 7.684352993965148e-05
# Epoch: 181, Batch: 4, Avg. Loss: 7.813255488872528e-05
# Epoch: 181, Batch: 6, Avg. Loss: 7.911401987075806e-05
# Epoch: 182, Batch: 2, Avg. Loss: 7.790573313832283e-05
# Epoch: 182, Batch: 4, Avg. Loss: 7.952211797237396e-05
# Epoch: 182, Batch: 6, Avg. Loss: 7.882493734359741e-05
# Epoch: 183, Batch: 2, Avg. Loss: 7.767930999398232e-05
# Epoch: 183, Batch: 4, Avg. Loss: 7.819413393735886e-05
# Epoch: 183, Batch: 6, Avg. Loss: 7.651788368821145e-05
# Epoch: 184, Batch: 2, Avg. Loss: 7.773613184690475e-05
# Epoch: 184, Batch: 4, Avg. Loss: 7.660755887627602e-05
# Epoch: 184, Batch: 6, Avg. Loss: 7.817764952778816e-05
# Epoch: 185, Batch: 2, Avg. Loss: 7.649286836385727e-05
# Epoch: 185, Batch: 4, Avg. Loss: 7.709264755249024e-05
# Epoch: 185, Batch: 6, Avg. Loss: 7.727361097931861e-05
# Epoch: 186, Batch: 2, Avg. Loss: 7.598749920725823e-05
# Epoch: 186, Batch: 4, Avg. Loss: 7.903392612934113e-05
# Epoch: 186, Batch: 6, Avg. Loss: 7.932217046618462e-05
# Epoch: 187, Batch: 2, Avg. Loss: 7.647286728024482e-05
# Epoch: 187, Batch: 4, Avg. Loss: 7.695282623171806e-05
# Epoch: 187, Batch: 6, Avg. Loss: 7.816369459033012e-05
# Epoch: 188, Batch: 2, Avg. Loss: 7.867870479822158e-05
# Epoch: 188, Batch: 4, Avg. Loss: 7.682510837912559e-05
# Epoch: 188, Batch: 6, Avg. Loss: 7.75168128311634e-05
# Epoch: 189, Batch: 2, Avg. Loss: 7.77873583137989e-05
# Epoch: 189, Batch: 4, Avg. Loss: 8.119934052228927e-05
# Epoch: 189, Batch: 6, Avg. Loss: 7.619332149624825e-05
# Epoch: 190, Batch: 2, Avg. Loss: 8.001453056931496e-05
# Epoch: 190, Batch: 4, Avg. Loss: 7.859477400779724e-05
# Epoch: 190, Batch: 6, Avg. Loss: 7.575331255793571e-05
# Epoch: 191, Batch: 2, Avg. Loss: 7.844777777791024e-05
# Epoch: 191, Batch: 4, Avg. Loss: 7.708821445703506e-05
# Epoch: 191, Batch: 6, Avg. Loss: 7.937433570623397e-05
# Epoch: 192, Batch: 2, Avg. Loss: 7.892460748553276e-05
# Epoch: 192, Batch: 4, Avg. Loss: 7.781487703323365e-05
# Epoch: 192, Batch: 6, Avg. Loss: 7.874565199017525e-05
# Epoch: 193, Batch: 2, Avg. Loss: 7.922974973917008e-05
# Epoch: 193, Batch: 4, Avg. Loss: 7.958326861262322e-05
# Epoch: 193, Batch: 6, Avg. Loss: 7.898488268256188e-05
# Epoch: 194, Batch: 2, Avg. Loss: 7.790964096784591e-05
# Epoch: 194, Batch: 4, Avg. Loss: 7.894780114293098e-05
# Epoch: 194, Batch: 6, Avg. Loss: 7.684411108493805e-05
# Epoch: 195, Batch: 2, Avg. Loss: 8.227531611919403e-05
# Epoch: 195, Batch: 4, Avg. Loss: 7.795150950551033e-05
# Epoch: 195, Batch: 6, Avg. Loss: 7.943914830684662e-05
# Epoch: 196, Batch: 2, Avg. Loss: 7.598602771759034e-05
# Epoch: 196, Batch: 4, Avg. Loss: 7.854816690087319e-05
# Epoch: 196, Batch: 6, Avg. Loss: 7.762137055397034e-05
# Epoch: 197, Batch: 2, Avg. Loss: 7.858394458889961e-05
# Epoch: 197, Batch: 4, Avg. Loss: 7.711462676525116e-05
# Epoch: 197, Batch: 6, Avg. Loss: 7.684561610221863e-05
# Epoch: 198, Batch: 2, Avg. Loss: 7.866264879703522e-05
# Epoch: 198, Batch: 4, Avg. Loss: 7.570730894804001e-05
# Epoch: 198, Batch: 6, Avg. Loss: 7.894016429781914e-05
# Epoch: 199, Batch: 2, Avg. Loss: 7.83773511648178e-05
# Epoch: 199, Batch: 4, Avg. Loss: 7.88285844027996e-05
# Epoch: 199, Batch: 6, Avg. Loss: 7.633264735341072e-05
# Epoch: 200, Batch: 2, Avg. Loss: 7.77418203651905e-05
# Epoch: 200, Batch: 4, Avg. Loss: 7.901959121227264e-05
# Epoch: 200, Batch: 6, Avg. Loss: 7.58305937051773e-05
# Epoch: 201, Batch: 2, Avg. Loss: 7.962965592741966e-05
# Epoch: 201, Batch: 4, Avg. Loss: 7.625377550721169e-05
# Epoch: 201, Batch: 6, Avg. Loss: 7.700393721461296e-05
# Epoch: 202, Batch: 2, Avg. Loss: 7.6515831053257e-05
# Epoch: 202, Batch: 4, Avg. Loss: 7.750687375664711e-05
# Epoch: 202, Batch: 6, Avg. Loss: 7.792086526751519e-05
# Epoch: 203, Batch: 2, Avg. Loss: 7.639136910438537e-05
# Epoch: 203, Batch: 4, Avg. Loss: 7.848640158772468e-05
# Epoch: 203, Batch: 6, Avg. Loss: 7.659653574228286e-05
# Epoch: 204, Batch: 2, Avg. Loss: 7.780499011278152e-05
# Epoch: 204, Batch: 4, Avg. Loss: 7.843965291976929e-05
# Epoch: 204, Batch: 6, Avg. Loss: 7.597167044878007e-05
# Epoch: 205, Batch: 2, Avg. Loss: 7.60330967605114e-05
# Epoch: 205, Batch: 4, Avg. Loss: 7.947825640439987e-05
# Epoch: 205, Batch: 6, Avg. Loss: 7.71566741168499e-05
# Epoch: 206, Batch: 2, Avg. Loss: 7.609995082020759e-05
# Epoch: 206, Batch: 4, Avg. Loss: 7.747344300150871e-05
# Epoch: 206, Batch: 6, Avg. Loss: 7.817462086677551e-05
# Epoch: 207, Batch: 2, Avg. Loss: 7.797712460160256e-05
# Epoch: 207, Batch: 4, Avg. Loss: 7.579444348812104e-05
# Epoch: 207, Batch: 6, Avg. Loss: 7.695567607879639e-05
# Epoch: 208, Batch: 2, Avg. Loss: 7.746047526597976e-05
# Epoch: 208, Batch: 4, Avg. Loss: 7.69447684288025e-05
# Epoch: 208, Batch: 6, Avg. Loss: 7.725219056010246e-05
# Epoch: 209, Batch: 2, Avg. Loss: 7.739173993468285e-05
# Epoch: 209, Batch: 4, Avg. Loss: 7.665334269404411e-05
# Epoch: 209, Batch: 6, Avg. Loss: 7.714369520545005e-05
# Epoch: 210, Batch: 2, Avg. Loss: 7.845484465360642e-05
# Epoch: 210, Batch: 4, Avg. Loss: 7.812792807817459e-05
# Epoch: 210, Batch: 6, Avg. Loss: 7.607658952474594e-05
# Epoch: 211, Batch: 2, Avg. Loss: 7.74170272052288e-05
# Epoch: 211, Batch: 4, Avg. Loss: 7.71855115890503e-05
# Epoch: 211, Batch: 6, Avg. Loss: 7.63654075562954e-05
# Epoch: 212, Batch: 2, Avg. Loss: 7.806287705898285e-05
# Epoch: 212, Batch: 4, Avg. Loss: 7.576796039938927e-05
# Epoch: 212, Batch: 6, Avg. Loss: 7.651660218834877e-05
# Epoch: 213, Batch: 2, Avg. Loss: 7.677759230136872e-05
# Epoch: 213, Batch: 4, Avg. Loss: 7.568518817424774e-05
# Epoch: 213, Batch: 6, Avg. Loss: 7.626838982105255e-05
# Epoch: 214, Batch: 2, Avg. Loss: 7.537644356489181e-05
# Epoch: 214, Batch: 4, Avg. Loss: 7.614766061306e-05
# Epoch: 214, Batch: 6, Avg. Loss: 7.861920818686486e-05
# Epoch: 215, Batch: 2, Avg. Loss: 7.68960528075695e-05
# Epoch: 215, Batch: 4, Avg. Loss: 7.675343751907349e-05
# Epoch: 215, Batch: 6, Avg. Loss: 7.718483731150627e-05
# Epoch: 216, Batch: 2, Avg. Loss: 7.656488567590713e-05
# Epoch: 216, Batch: 4, Avg. Loss: 7.597223296761513e-05
# Epoch: 216, Batch: 6, Avg. Loss: 7.543283700942994e-05
# Epoch: 217, Batch: 2, Avg. Loss: 7.540600746870041e-05
# Epoch: 217, Batch: 4, Avg. Loss: 7.581799849867821e-05
# Epoch: 217, Batch: 6, Avg. Loss: 7.708441093564033e-05
# Epoch: 218, Batch: 2, Avg. Loss: 7.72545114159584e-05
# Epoch: 218, Batch: 4, Avg. Loss: 7.760142162442208e-05
# Epoch: 218, Batch: 6, Avg. Loss: 7.847436890006065e-05
# Epoch: 219, Batch: 2, Avg. Loss: 7.797503098845482e-05
# Epoch: 219, Batch: 4, Avg. Loss: 7.720382511615753e-05
# Epoch: 219, Batch: 6, Avg. Loss: 7.494711875915527e-05
# Epoch: 220, Batch: 2, Avg. Loss: 7.63440728187561e-05
# Epoch: 220, Batch: 4, Avg. Loss: 7.586227357387543e-05
# Epoch: 220, Batch: 6, Avg. Loss: 7.706977427005767e-05
# Epoch: 221, Batch: 2, Avg. Loss: 7.613927125930786e-05
# Epoch: 221, Batch: 4, Avg. Loss: 7.735928893089294e-05
# Epoch: 221, Batch: 6, Avg. Loss: 7.726629078388214e-05
# Epoch: 222, Batch: 2, Avg. Loss: 7.744489982724189e-05
# Epoch: 222, Batch: 4, Avg. Loss: 7.669532671570778e-05
# Epoch: 222, Batch: 6, Avg. Loss: 7.600929588079453e-05
# Epoch: 223, Batch: 2, Avg. Loss: 7.645681872963906e-05
# Epoch: 223, Batch: 4, Avg. Loss: 7.767180353403092e-05
# Epoch: 223, Batch: 6, Avg. Loss: 7.721828296780586e-05
# Epoch: 224, Batch: 2, Avg. Loss: 7.672348245978355e-05
# Epoch: 224, Batch: 4, Avg. Loss: 7.636058703064918e-05
# Epoch: 224, Batch: 6, Avg. Loss: 7.621071860194206e-05
# Epoch: 225, Batch: 2, Avg. Loss: 7.54738636314869e-05
# Epoch: 225, Batch: 4, Avg. Loss: 7.690732926130294e-05
# Epoch: 225, Batch: 6, Avg. Loss: 7.718652486801147e-05
# Epoch: 226, Batch: 2, Avg. Loss: 7.632376998662949e-05
# Epoch: 226, Batch: 4, Avg. Loss: 7.704994827508926e-05
# Epoch: 226, Batch: 6, Avg. Loss: 7.696640491485595e-05
# Epoch: 227, Batch: 2, Avg. Loss: 7.606843858957291e-05
# Epoch: 227, Batch: 4, Avg. Loss: 7.688883319497108e-05
# Epoch: 227, Batch: 6, Avg. Loss: 7.652090862393379e-05
# Epoch: 228, Batch: 2, Avg. Loss: 7.501943409442902e-05
# Epoch: 228, Batch: 4, Avg. Loss: 7.766743376851082e-05
# Epoch: 228, Batch: 6, Avg. Loss: 7.539711892604827e-05
# Epoch: 229, Batch: 2, Avg. Loss: 7.531735301017762e-05
# Epoch: 229, Batch: 4, Avg. Loss: 7.52377137541771e-05
# Epoch: 229, Batch: 6, Avg. Loss: 7.585868239402771e-05
# Epoch: 230, Batch: 2, Avg. Loss: 7.558892294764519e-05
# Epoch: 230, Batch: 4, Avg. Loss: 7.610305398702622e-05
# Epoch: 230, Batch: 6, Avg. Loss: 7.727230340242386e-05
# Epoch: 231, Batch: 2, Avg. Loss: 7.635495066642761e-05
# Epoch: 231, Batch: 4, Avg. Loss: 7.5759869068861e-05
# Epoch: 231, Batch: 6, Avg. Loss: 7.730302959680557e-05
# Epoch: 232, Batch: 2, Avg. Loss: 7.602544501423835e-05
# Epoch: 232, Batch: 4, Avg. Loss: 7.62244090437889e-05
# Epoch: 232, Batch: 6, Avg. Loss: 7.728511467576026e-05
# Epoch: 233, Batch: 2, Avg. Loss: 7.673413306474686e-05
# Epoch: 233, Batch: 4, Avg. Loss: 7.574177533388137e-05
# Epoch: 233, Batch: 6, Avg. Loss: 7.444793730974198e-05
# Epoch: 234, Batch: 2, Avg. Loss: 8.027514815330505e-05
# Epoch: 234, Batch: 4, Avg. Loss: 7.576664164662362e-05
# Epoch: 234, Batch: 6, Avg. Loss: 7.554058358073235e-05
# Epoch: 235, Batch: 2, Avg. Loss: 7.466736435890197e-05
# Epoch: 235, Batch: 4, Avg. Loss: 7.594497129321098e-05
# Epoch: 235, Batch: 6, Avg. Loss: 7.671743631362915e-05
# Epoch: 236, Batch: 2, Avg. Loss: 7.749615982174874e-05
# Epoch: 236, Batch: 4, Avg. Loss: 7.482879981398583e-05
# Epoch: 236, Batch: 6, Avg. Loss: 7.651829347014428e-05
# Epoch: 237, Batch: 2, Avg. Loss: 7.586181908845902e-05
# Epoch: 237, Batch: 4, Avg. Loss: 7.521575689315796e-05
# Epoch: 237, Batch: 6, Avg. Loss: 7.520768791437149e-05
# Epoch: 238, Batch: 2, Avg. Loss: 7.511837780475617e-05
# Epoch: 238, Batch: 4, Avg. Loss: 7.516004890203476e-05
# Epoch: 238, Batch: 6, Avg. Loss: 7.626941427588463e-05
# Epoch: 239, Batch: 2, Avg. Loss: 7.513534650206567e-05
# Epoch: 239, Batch: 4, Avg. Loss: 7.54743404686451e-05
# Epoch: 239, Batch: 6, Avg. Loss: 7.669429108500481e-05
# Epoch: 240, Batch: 2, Avg. Loss: 7.697131112217904e-05
# Epoch: 240, Batch: 4, Avg. Loss: 7.682260870933533e-05
# Epoch: 240, Batch: 6, Avg. Loss: 7.496759295463562e-05
# Epoch: 241, Batch: 2, Avg. Loss: 7.663146033883094e-05
# Epoch: 241, Batch: 4, Avg. Loss: 7.530917972326278e-05
# Epoch: 241, Batch: 6, Avg. Loss: 7.438397035002708e-05
# Epoch: 242, Batch: 2, Avg. Loss: 7.673932239413262e-05
# Epoch: 242, Batch: 4, Avg. Loss: 7.507428154349326e-05
# Epoch: 242, Batch: 6, Avg. Loss: 7.65766054391861e-05
# Epoch: 243, Batch: 2, Avg. Loss: 7.819613069295884e-05
# Epoch: 243, Batch: 4, Avg. Loss: 7.643408700823783e-05
# Epoch: 243, Batch: 6, Avg. Loss: 7.514602318406105e-05
# Epoch: 244, Batch: 2, Avg. Loss: 7.768172025680541e-05
# Epoch: 244, Batch: 4, Avg. Loss: 7.56099708378315e-05
# Epoch: 244, Batch: 6, Avg. Loss: 7.701840624213219e-05
# Epoch: 245, Batch: 2, Avg. Loss: 7.551297545433045e-05
# Epoch: 245, Batch: 4, Avg. Loss: 7.608393952250481e-05
# Epoch: 245, Batch: 6, Avg. Loss: 7.621295750141143e-05
# Epoch: 246, Batch: 2, Avg. Loss: 7.523668184876442e-05
# Epoch: 246, Batch: 4, Avg. Loss: 7.48000256717205e-05
# Epoch: 246, Batch: 6, Avg. Loss: 7.70290568470955e-05
# Epoch: 247, Batch: 2, Avg. Loss: 7.546084374189378e-05
# Epoch: 247, Batch: 4, Avg. Loss: 7.579560205340385e-05
# Epoch: 247, Batch: 6, Avg. Loss: 7.499173656105995e-05
# Epoch: 248, Batch: 2, Avg. Loss: 7.73954950273037e-05
# Epoch: 248, Batch: 4, Avg. Loss: 7.508238404989243e-05
# Epoch: 248, Batch: 6, Avg. Loss: 7.508997991681098e-05
# Epoch: 249, Batch: 2, Avg. Loss: 7.667787000536919e-05
# Epoch: 249, Batch: 4, Avg. Loss: 7.485462725162506e-05
# Epoch: 249, Batch: 6, Avg. Loss: 7.606640830636024e-05
# Epoch: 250, Batch: 2, Avg. Loss: 7.483342289924621e-05
# Epoch: 250, Batch: 4, Avg. Loss: 7.635995745658875e-05
# Epoch: 250, Batch: 6, Avg. Loss: 7.62135423719883e-05
# Epoch: 251, Batch: 2, Avg. Loss: 7.610100135207176e-05
# Epoch: 251, Batch: 4, Avg. Loss: 7.564205676317214e-05
# Epoch: 251, Batch: 6, Avg. Loss: 7.593873143196106e-05
# Epoch: 252, Batch: 2, Avg. Loss: 7.561671361327171e-05
# Epoch: 252, Batch: 4, Avg. Loss: 7.603923231363297e-05
# Epoch: 252, Batch: 6, Avg. Loss: 7.614410296082496e-05
# Epoch: 253, Batch: 2, Avg. Loss: 7.654500752687454e-05
# Epoch: 253, Batch: 4, Avg. Loss: 7.52657949924469e-05
# Epoch: 253, Batch: 6, Avg. Loss: 7.717543467879295e-05
# Epoch: 254, Batch: 2, Avg. Loss: 7.473723590373993e-05
# Epoch: 254, Batch: 4, Avg. Loss: 7.479483261704445e-05
# Epoch: 254, Batch: 6, Avg. Loss: 7.423289865255355e-05
# Epoch: 255, Batch: 2, Avg. Loss: 7.74858221411705e-05
# Epoch: 255, Batch: 4, Avg. Loss: 7.755514234304428e-05
# Epoch: 255, Batch: 6, Avg. Loss: 7.860960066318512e-05
# Epoch: 256, Batch: 2, Avg. Loss: 7.779737561941147e-05
# Epoch: 256, Batch: 4, Avg. Loss: 7.8147292137146e-05
# Epoch: 256, Batch: 6, Avg. Loss: 8.023330569267273e-05
# Epoch: 257, Batch: 2, Avg. Loss: 7.983922958374024e-05
# Epoch: 257, Batch: 4, Avg. Loss: 7.656311988830567e-05
# Epoch: 257, Batch: 6, Avg. Loss: 7.625475153326988e-05
# Epoch: 258, Batch: 2, Avg. Loss: 7.720263302326202e-05
# Epoch: 258, Batch: 4, Avg. Loss: 7.60260596871376e-05
# Epoch: 258, Batch: 6, Avg. Loss: 7.476054504513741e-05
# Epoch: 259, Batch: 2, Avg. Loss: 7.583876326680183e-05
# Epoch: 259, Batch: 4, Avg. Loss: 7.61556290090084e-05
# Epoch: 259, Batch: 6, Avg. Loss: 7.482711970806122e-05
# Epoch: 260, Batch: 2, Avg. Loss: 7.505316659808159e-05
# Epoch: 260, Batch: 4, Avg. Loss: 7.479559257626534e-05
# Epoch: 260, Batch: 6, Avg. Loss: 7.572912424802781e-05
# Epoch: 261, Batch: 2, Avg. Loss: 7.508822903037072e-05
# Epoch: 261, Batch: 4, Avg. Loss: 7.419515028595925e-05
# Epoch: 261, Batch: 6, Avg. Loss: 7.504158094525337e-05
# Epoch: 262, Batch: 2, Avg. Loss: 7.50952996313572e-05
# Epoch: 262, Batch: 4, Avg. Loss: 7.491364702582359e-05
# Epoch: 262, Batch: 6, Avg. Loss: 7.615778595209122e-05
# Epoch: 263, Batch: 2, Avg. Loss: 7.743499055504798e-05
# Epoch: 263, Batch: 4, Avg. Loss: 7.520601525902748e-05
# Epoch: 263, Batch: 6, Avg. Loss: 7.505134120583534e-05
# Epoch: 264, Batch: 2, Avg. Loss: 7.715033367276191e-05
# Epoch: 264, Batch: 4, Avg. Loss: 7.412320747971534e-05
# Epoch: 264, Batch: 6, Avg. Loss: 7.491666451096535e-05
# Epoch: 265, Batch: 2, Avg. Loss: 7.444950938224792e-05
# Epoch: 265, Batch: 4, Avg. Loss: 7.703565433621406e-05
# Epoch: 265, Batch: 6, Avg. Loss: 7.664627954363824e-05
# Epoch: 266, Batch: 2, Avg. Loss: 7.767736539244652e-05
# Epoch: 266, Batch: 4, Avg. Loss: 7.665437087416649e-05
# Epoch: 266, Batch: 6, Avg. Loss: 7.59383738040924e-05
# Epoch: 267, Batch: 2, Avg. Loss: 7.490446045994758e-05
# Epoch: 267, Batch: 4, Avg. Loss: 7.684576511383057e-05
# Epoch: 267, Batch: 6, Avg. Loss: 7.677141949534416e-05
# Epoch: 268, Batch: 2, Avg. Loss: 7.560375705361366e-05
# Epoch: 268, Batch: 4, Avg. Loss: 7.553817331790924e-05
# Epoch: 268, Batch: 6, Avg. Loss: 7.571454718708992e-05
# Epoch: 269, Batch: 2, Avg. Loss: 7.495063170790672e-05
# Epoch: 269, Batch: 4, Avg. Loss: 7.556391134858131e-05
# Epoch: 269, Batch: 6, Avg. Loss: 7.544288039207459e-05
# Epoch: 270, Batch: 2, Avg. Loss: 7.593128830194474e-05
# Epoch: 270, Batch: 4, Avg. Loss: 7.53336288034916e-05
# Epoch: 270, Batch: 6, Avg. Loss: 7.596486061811447e-05
# Epoch: 271, Batch: 2, Avg. Loss: 7.416419312357902e-05
# Epoch: 271, Batch: 4, Avg. Loss: 7.600300014019013e-05
# Epoch: 271, Batch: 6, Avg. Loss: 7.380431145429611e-05
# Epoch: 272, Batch: 2, Avg. Loss: 7.561980932950974e-05
# Epoch: 272, Batch: 4, Avg. Loss: 7.508909329771996e-05
# Epoch: 272, Batch: 6, Avg. Loss: 7.602667063474655e-05
# Epoch: 273, Batch: 2, Avg. Loss: 7.362207025289536e-05
# Epoch: 273, Batch: 4, Avg. Loss: 7.58994072675705e-05
# Epoch: 273, Batch: 6, Avg. Loss: 7.534050568938255e-05
# Epoch: 274, Batch: 2, Avg. Loss: 7.5648233294487e-05
# Epoch: 274, Batch: 4, Avg. Loss: 7.410399988293648e-05
# Epoch: 274, Batch: 6, Avg. Loss: 7.68553763628006e-05
# Epoch: 275, Batch: 2, Avg. Loss: 7.344143092632294e-05
# Epoch: 275, Batch: 4, Avg. Loss: 7.475841417908669e-05
# Epoch: 275, Batch: 6, Avg. Loss: 7.559146732091904e-05
# Epoch: 276, Batch: 2, Avg. Loss: 7.579439505934715e-05
# Epoch: 276, Batch: 4, Avg. Loss: 7.407419010996818e-05
# Epoch: 276, Batch: 6, Avg. Loss: 7.680615410208702e-05
# Epoch: 277, Batch: 2, Avg. Loss: 7.491511479020119e-05
# Epoch: 277, Batch: 4, Avg. Loss: 7.621420174837113e-05
# Epoch: 277, Batch: 6, Avg. Loss: 7.537882402539253e-05
# Epoch: 278, Batch: 2, Avg. Loss: 7.496872916817665e-05
# Epoch: 278, Batch: 4, Avg. Loss: 7.612540200352669e-05
# Epoch: 278, Batch: 6, Avg. Loss: 7.483888790011406e-05
# Epoch: 279, Batch: 2, Avg. Loss: 7.579904422163964e-05
# Epoch: 279, Batch: 4, Avg. Loss: 7.473443076014518e-05
# Epoch: 279, Batch: 6, Avg. Loss: 7.417164742946624e-05
# Epoch: 280, Batch: 2, Avg. Loss: 7.563458010554314e-05
# Epoch: 280, Batch: 4, Avg. Loss: 7.530994713306427e-05
# Epoch: 280, Batch: 6, Avg. Loss: 7.550347968935967e-05
# Epoch: 281, Batch: 2, Avg. Loss: 7.463434338569641e-05
# Epoch: 281, Batch: 4, Avg. Loss: 7.464854791760444e-05
# Epoch: 281, Batch: 6, Avg. Loss: 7.583887130022049e-05
# Epoch: 282, Batch: 2, Avg. Loss: 7.312015071511269e-05
# Epoch: 282, Batch: 4, Avg. Loss: 7.50325471162796e-05
# Epoch: 282, Batch: 6, Avg. Loss: 7.438241317868233e-05
# Epoch: 283, Batch: 2, Avg. Loss: 7.479279488325119e-05
# Epoch: 283, Batch: 4, Avg. Loss: 7.633844390511513e-05
# Epoch: 283, Batch: 6, Avg. Loss: 7.502914592623711e-05
# Epoch: 284, Batch: 2, Avg. Loss: 7.364584505558014e-05
# Epoch: 284, Batch: 4, Avg. Loss: 7.384018227458e-05
# Epoch: 284, Batch: 6, Avg. Loss: 7.452875003218651e-05
# Epoch: 285, Batch: 2, Avg. Loss: 7.442463934421539e-05
# Epoch: 285, Batch: 4, Avg. Loss: 7.519472762942314e-05
# Epoch: 285, Batch: 6, Avg. Loss: 7.467198371887207e-05
# Epoch: 286, Batch: 2, Avg. Loss: 7.537630572915077e-05
# Epoch: 286, Batch: 4, Avg. Loss: 7.409441843628883e-05
# Epoch: 286, Batch: 6, Avg. Loss: 7.34783336520195e-05
# Epoch: 287, Batch: 2, Avg. Loss: 7.424159720540047e-05
# Epoch: 287, Batch: 4, Avg. Loss: 7.395137846469879e-05
# Epoch: 287, Batch: 6, Avg. Loss: 7.568389922380447e-05
# Epoch: 288, Batch: 2, Avg. Loss: 7.511205598711968e-05
# Epoch: 288, Batch: 4, Avg. Loss: 7.578404247760773e-05
# Epoch: 288, Batch: 6, Avg. Loss: 7.508647441864013e-05
# Epoch: 289, Batch: 2, Avg. Loss: 7.407961413264275e-05
# Epoch: 289, Batch: 4, Avg. Loss: 7.499335333704948e-05
# Epoch: 289, Batch: 6, Avg. Loss: 7.55377672612667e-05
# Epoch: 290, Batch: 2, Avg. Loss: 7.626751065254211e-05
# Epoch: 290, Batch: 4, Avg. Loss: 7.354820147156715e-05
# Epoch: 290, Batch: 6, Avg. Loss: 7.449669018387794e-05
# Epoch: 291, Batch: 2, Avg. Loss: 7.373930141329765e-05
# Epoch: 291, Batch: 4, Avg. Loss: 7.345541566610336e-05
# Epoch: 291, Batch: 6, Avg. Loss: 7.507862895727157e-05
# Epoch: 292, Batch: 2, Avg. Loss: 7.440569624304772e-05
# Epoch: 292, Batch: 4, Avg. Loss: 7.389073446393013e-05
# Epoch: 292, Batch: 6, Avg. Loss: 7.538708671927452e-05
# Epoch: 293, Batch: 2, Avg. Loss: 7.467057928442955e-05
# Epoch: 293, Batch: 4, Avg. Loss: 7.363060116767883e-05
# Epoch: 293, Batch: 6, Avg. Loss: 7.380229234695434e-05
# Epoch: 294, Batch: 2, Avg. Loss: 7.336464896798133e-05
# ...
# Epoch: 404, Batch: 2, Avg. Loss: 7.156151533126831e-05
# Epoch: 404, Batch: 4, Avg. Loss: 7.310176268219948e-05
# Epoch: 404, Batch: 6, Avg. Loss: 7.203597575426101e-05
# Epoch: 405, Batch: 2, Avg. Loss: 7.27127157151699e-05
# Epoch: 405, Batch: 4, Avg. Loss: 7.014458999037742e-05
# Epoch: 405, Batch: 6, Avg. Loss: 7.05568864941597e-05
# Epoch: 406, Batch: 2, Avg. Loss: 7.06944540143013e-05
# Epoch: 406, Batch: 4, Avg. Loss: 7.180356234312057e-05
# Epoch: 406, Batch: 6, Avg. Loss: 7.102635875344276e-05
# Epoch: 407, Batch: 2, Avg. Loss: 7.141181454062462e-05
# Epoch: 407, Batch: 4, Avg. Loss: 7.193419337272643e-05
# Epoch: 407, Batch: 6, Avg. Loss: 6.988850980997086e-05
# Epoch: 408, Batch: 2, Avg. Loss: 7.170996442437172e-05
# Epoch: 408, Batch: 4, Avg. Loss: 7.085837796330453e-05
# Epoch: 408, Batch: 6, Avg. Loss: 7.275927066802979e-05
# Epoch: 409, Batch: 2, Avg. Loss: 7.190889492630959e-05
# Epoch: 409, Batch: 4, Avg. Loss: 7.119399681687355e-05
# Epoch: 409, Batch: 6, Avg. Loss: 7.003698870539665e-05
# Epoch: 410, Batch: 2, Avg. Loss: 6.996357813477517e-05
# Epoch: 410, Batch: 4, Avg. Loss: 7.056471705436707e-05
# Epoch: 410, Batch: 6, Avg. Loss: 7.094118371605873e-05
# Epoch: 411, Batch: 2, Avg. Loss: 7.174136862158775e-05
# Epoch: 411, Batch: 4, Avg. Loss: 7.153815031051636e-05
# Epoch: 411, Batch: 6, Avg. Loss: 7.018272206187248e-05
# Epoch: 412, Batch: 2, Avg. Loss: 6.955407187342643e-05
# Epoch: 412, Batch: 4, Avg. Loss: 7.167252525687218e-05
# Epoch: 412, Batch: 6, Avg. Loss: 7.066617161035538e-05
# Epoch: 413, Batch: 2, Avg. Loss: 7.287460193037987e-05
# Epoch: 413, Batch: 4, Avg. Loss: 7.061419636011123e-05
# Epoch: 413, Batch: 6, Avg. Loss: 7.136514782905579e-05
# Epoch: 414, Batch: 2, Avg. Loss: 7.33967237174511e-05
# Epoch: 414, Batch: 4, Avg. Loss: 7.062634080648423e-05
# Epoch: 414, Batch: 6, Avg. Loss: 7.161599770188332e-05
# Epoch: 415, Batch: 2, Avg. Loss: 7.154195010662079e-05
# Epoch: 415, Batch: 4, Avg. Loss: 7.25877657532692e-05
# Epoch: 415, Batch: 6, Avg. Loss: 7.163594663143158e-05
# Epoch: 416, Batch: 2, Avg. Loss: 7.1525689214468e-05
# Epoch: 416, Batch: 4, Avg. Loss: 7.214665412902832e-05
# Epoch: 416, Batch: 6, Avg. Loss: 7.24736824631691e-05
# Epoch: 417, Batch: 2, Avg. Loss: 7.17710740864277e-05
# Epoch: 417, Batch: 4, Avg. Loss: 7.204937934875488e-05
# Epoch: 417, Batch: 6, Avg. Loss: 7.164980843663215e-05
# Epoch: 418, Batch: 2, Avg. Loss: 7.100426778197288e-05
# Epoch: 418, Batch: 4, Avg. Loss: 7.128032296895981e-05
# Epoch: 418, Batch: 6, Avg. Loss: 7.114378735423088e-05
# Epoch: 419, Batch: 2, Avg. Loss: 7.08564594388008e-05
# Epoch: 419, Batch: 4, Avg. Loss: 7.098563015460969e-05
# Epoch: 419, Batch: 6, Avg. Loss: 7.090305909514427e-05
# Epoch: 420, Batch: 2, Avg. Loss: 7.026765495538712e-05
# Epoch: 420, Batch: 4, Avg. Loss: 7.145373895764351e-05
# Epoch: 420, Batch: 6, Avg. Loss: 7.212313264608383e-05
# Epoch: 421, Batch: 2, Avg. Loss: 7.108182460069657e-05
# Epoch: 421, Batch: 4, Avg. Loss: 7.046622782945632e-05
# Epoch: 421, Batch: 6, Avg. Loss: 7.235559821128846e-05
# Epoch: 422, Batch: 2, Avg. Loss: 7.287131622433662e-05
# Epoch: 422, Batch: 4, Avg. Loss: 7.03621283173561e-05
# Epoch: 422, Batch: 6, Avg. Loss: 7.337848842144012e-05
# Epoch: 423, Batch: 2, Avg. Loss: 7.207059860229492e-05
# Epoch: 423, Batch: 4, Avg. Loss: 7.08092600107193e-05
# Epoch: 423, Batch: 6, Avg. Loss: 7.074950635433197e-05
# Epoch: 424, Batch: 2, Avg. Loss: 7.04370141029358e-05
# Epoch: 424, Batch: 4, Avg. Loss: 7.095382362604142e-05
# Epoch: 424, Batch: 6, Avg. Loss: 7.225951179862022e-05
# Epoch: 425, Batch: 2, Avg. Loss: 7.163782045245171e-05
# Epoch: 425, Batch: 4, Avg. Loss: 7.119020447134971e-05
# Epoch: 425, Batch: 6, Avg. Loss: 7.323455438017845e-05
# Epoch: 426, Batch: 2, Avg. Loss: 7.140998542308808e-05
# Epoch: 426, Batch: 4, Avg. Loss: 7.133716344833374e-05
# Epoch: 426, Batch: 6, Avg. Loss: 7.00579471886158e-05
# Epoch: 427, Batch: 2, Avg. Loss: 7.317448407411575e-05
# Epoch: 427, Batch: 4, Avg. Loss: 7.105934619903565e-05
# Epoch: 427, Batch: 6, Avg. Loss: 7.045769691467286e-05
# Epoch: 428, Batch: 2, Avg. Loss: 7.03553445637226e-05
# Epoch: 428, Batch: 4, Avg. Loss: 7.137095928192138e-05
# Epoch: 428, Batch: 6, Avg. Loss: 7.127706706523896e-05
# Epoch: 429, Batch: 2, Avg. Loss: 7.189236581325531e-05
# Epoch: 429, Batch: 4, Avg. Loss: 7.058428600430489e-05
# Epoch: 429, Batch: 6, Avg. Loss: 7.113848626613617e-05
# Epoch: 430, Batch: 2, Avg. Loss: 7.025505229830742e-05
# Epoch: 430, Batch: 4, Avg. Loss: 7.465553656220436e-05
# Epoch: 430, Batch: 6, Avg. Loss: 7.097576558589935e-05
# Epoch: 431, Batch: 2, Avg. Loss: 7.130247354507447e-05
# Epoch: 431, Batch: 4, Avg. Loss: 7.02211894094944e-05
# Epoch: 431, Batch: 6, Avg. Loss: 7.030048221349716e-05
# Epoch: 432, Batch: 2, Avg. Loss: 7.05133005976677e-05
# Epoch: 432, Batch: 4, Avg. Loss: 7.148298993706703e-05
# Epoch: 432, Batch: 6, Avg. Loss: 7.033055275678635e-05
# Epoch: 433, Batch: 2, Avg. Loss: 7.0305485278368e-05
# Epoch: 433, Batch: 4, Avg. Loss: 7.06576220691204e-05
# Epoch: 433, Batch: 6, Avg. Loss: 7.231928035616875e-05
# Epoch: 434, Batch: 2, Avg. Loss: 7.16368816792965e-05
# Epoch: 434, Batch: 4, Avg. Loss: 7.059864699840546e-05
# Epoch: 434, Batch: 6, Avg. Loss: 6.95115365087986e-05
# Epoch: 435, Batch: 2, Avg. Loss: 7.020698115229607e-05
# Epoch: 435, Batch: 4, Avg. Loss: 7.122830301523209e-05
# Epoch: 435, Batch: 6, Avg. Loss: 6.864109635353089e-05
# Epoch: 436, Batch: 2, Avg. Loss: 6.961844116449356e-05
# Epoch: 436, Batch: 4, Avg. Loss: 7.057021930813789e-05
# Epoch: 436, Batch: 6, Avg. Loss: 7.087715342640876e-05
# Epoch: 437, Batch: 2, Avg. Loss: 7.028894498944282e-05
# Epoch: 437, Batch: 4, Avg. Loss: 7.118702679872513e-05
# Epoch: 437, Batch: 6, Avg. Loss: 7.142893224954605e-05
# Epoch: 438, Batch: 2, Avg. Loss: 7.114791497588158e-05
# Epoch: 438, Batch: 4, Avg. Loss: 7.137084752321243e-05
# Epoch: 438, Batch: 6, Avg. Loss: 7.072434946894645e-05
# Epoch: 439, Batch: 2, Avg. Loss: 7.198168337345124e-05
# Epoch: 439, Batch: 4, Avg. Loss: 7.044373452663422e-05
# Epoch: 439, Batch: 6, Avg. Loss: 7.187803834676743e-05
# Epoch: 440, Batch: 2, Avg. Loss: 7.36616626381874e-05
# Epoch: 440, Batch: 4, Avg. Loss: 7.408398017287254e-05
# Epoch: 440, Batch: 6, Avg. Loss: 7.157691568136215e-05
# Epoch: 441, Batch: 2, Avg. Loss: 7.172632589936256e-05
# Epoch: 441, Batch: 4, Avg. Loss: 7.190382853150368e-05
# Epoch: 441, Batch: 6, Avg. Loss: 7.181660458445549e-05
# Epoch: 442, Batch: 2, Avg. Loss: 7.258100807666778e-05
# Epoch: 442, Batch: 4, Avg. Loss: 7.036131992936135e-05
# Epoch: 442, Batch: 6, Avg. Loss: 7.208054512739181e-05
# Epoch: 443, Batch: 2, Avg. Loss: 7.22925178706646e-05
# Epoch: 443, Batch: 4, Avg. Loss: 7.128259912133216e-05
# Epoch: 443, Batch: 6, Avg. Loss: 7.185113430023193e-05
# Epoch: 444, Batch: 2, Avg. Loss: 7.104413583874702e-05
# Epoch: 444, Batch: 4, Avg. Loss: 7.043407112360001e-05
# Epoch: 444, Batch: 6, Avg. Loss: 7.095251604914665e-05
# Epoch: 445, Batch: 2, Avg. Loss: 7.156916707754136e-05
# Epoch: 445, Batch: 4, Avg. Loss: 7.026198878884316e-05
# Epoch: 445, Batch: 6, Avg. Loss: 7.056720554828644e-05
# Epoch: 446, Batch: 2, Avg. Loss: 7.059178873896599e-05
# Epoch: 446, Batch: 4, Avg. Loss: 7.197106257081031e-05
# Epoch: 446, Batch: 6, Avg. Loss: 6.997587904334069e-05
# Epoch: 447, Batch: 2, Avg. Loss: 7.130714133381844e-05
# Epoch: 447, Batch: 4, Avg. Loss: 7.049062103033066e-05
# Epoch: 447, Batch: 6, Avg. Loss: 6.979114934802056e-05
# Epoch: 448, Batch: 2, Avg. Loss: 7.20461644232273e-05
# Epoch: 448, Batch: 4, Avg. Loss: 7.057815417647362e-05
# Epoch: 448, Batch: 6, Avg. Loss: 7.121894136071205e-05
# Epoch: 449, Batch: 2, Avg. Loss: 7.071857899427414e-05
# Epoch: 449, Batch: 4, Avg. Loss: 7.228058949112892e-05
# Epoch: 449, Batch: 6, Avg. Loss: 7.005248591303825e-05
# Epoch: 450, Batch: 2, Avg. Loss: 6.977030262351036e-05
# Epoch: 450, Batch: 4, Avg. Loss: 7.054566591978073e-05
# Epoch: 450, Batch: 6, Avg. Loss: 7.052765414118767e-05
# Epoch: 451, Batch: 2, Avg. Loss: 7.24041610956192e-05
# Epoch: 451, Batch: 4, Avg. Loss: 7.160624489188194e-05
# Epoch: 451, Batch: 6, Avg. Loss: 7.107210904359818e-05
# Epoch: 452, Batch: 2, Avg. Loss: 7.139220088720322e-05
# Epoch: 452, Batch: 4, Avg. Loss: 7.07228034734726e-05
# Epoch: 452, Batch: 6, Avg. Loss: 7.068676501512527e-05
# Epoch: 453, Batch: 2, Avg. Loss: 7.076782360672951e-05
# Epoch: 453, Batch: 4, Avg. Loss: 7.120263576507569e-05
# Epoch: 453, Batch: 6, Avg. Loss: 7.00950101017952e-05
# Epoch: 454, Batch: 2, Avg. Loss: 7.11580589413643e-05
# Epoch: 454, Batch: 4, Avg. Loss: 6.92010261118412e-05
# Epoch: 454, Batch: 6, Avg. Loss: 7.209940254688263e-05
# Epoch: 455, Batch: 2, Avg. Loss: 7.267236337065697e-05
# Epoch: 455, Batch: 4, Avg. Loss: 7.054319605231284e-05
# Epoch: 455, Batch: 6, Avg. Loss: 7.043389603495598e-05
# Epoch: 456, Batch: 2, Avg. Loss: 7.025805860757828e-05
# Epoch: 456, Batch: 4, Avg. Loss: 7.238109782338142e-05
# Epoch: 456, Batch: 6, Avg. Loss: 7.085711508989335e-05
# Epoch: 457, Batch: 2, Avg. Loss: 6.939075514674186e-05
# Epoch: 457, Batch: 4, Avg. Loss: 7.02156089246273e-05
# Epoch: 457, Batch: 6, Avg. Loss: 7.177167758345603e-05
# Epoch: 458, Batch: 2, Avg. Loss: 7.094473764300346e-05
# Epoch: 458, Batch: 4, Avg. Loss: 7.139156758785247e-05
# Epoch: 458, Batch: 6, Avg. Loss: 7.06806592643261e-05
# Epoch: 459, Batch: 2, Avg. Loss: 7.415379956364631e-05
# Epoch: 459, Batch: 4, Avg. Loss: 7.023233547806739e-05
# Epoch: 459, Batch: 6, Avg. Loss: 7.036325708031654e-05
# Epoch: 460, Batch: 2, Avg. Loss: 7.3456559330225e-05
# Epoch: 460, Batch: 4, Avg. Loss: 7.079567387700081e-05
# Epoch: 460, Batch: 6, Avg. Loss: 7.038449868559837e-05
# Epoch: 461, Batch: 2, Avg. Loss: 7.09259919822216e-05
# Epoch: 461, Batch: 4, Avg. Loss: 7.119709998369217e-05
# Epoch: 461, Batch: 6, Avg. Loss: 7.026186585426331e-05
# Epoch: 462, Batch: 2, Avg. Loss: 7.158425077795982e-05
# Epoch: 462, Batch: 4, Avg. Loss: 7.151163369417191e-05
# Epoch: 462, Batch: 6, Avg. Loss: 7.303240522742272e-05
# Epoch: 463, Batch: 2, Avg. Loss: 7.043837010860443e-05
# Epoch: 463, Batch: 4, Avg. Loss: 7.040287554264069e-05
# Epoch: 463, Batch: 6, Avg. Loss: 7.195176184177398e-05
# Epoch: 464, Batch: 2, Avg. Loss: 6.976878643035889e-05
# Epoch: 464, Batch: 4, Avg. Loss: 7.055005431175231e-05
# Epoch: 464, Batch: 6, Avg. Loss: 6.930920109152793e-05
# Epoch: 465, Batch: 2, Avg. Loss: 7.07351453602314e-05
# Epoch: 465, Batch: 4, Avg. Loss: 7.058155909180641e-05
# Epoch: 465, Batch: 6, Avg. Loss: 7.066212221980095e-05
# Epoch: 466, Batch: 2, Avg. Loss: 6.990402936935425e-05
# Epoch: 466, Batch: 4, Avg. Loss: 6.92945346236229e-05
# Epoch: 466, Batch: 6, Avg. Loss: 7.081496343016624e-05
# Epoch: 467, Batch: 2, Avg. Loss: 7.173274457454682e-05
# Epoch: 467, Batch: 4, Avg. Loss: 7.025706022977829e-05
# Epoch: 467, Batch: 6, Avg. Loss: 7.138707488775253e-05
# Epoch: 468, Batch: 2, Avg. Loss: 7.104941457509995e-05
# Epoch: 468, Batch: 4, Avg. Loss: 7.139920443296433e-05
# Epoch: 468, Batch: 6, Avg. Loss: 7.051809877157212e-05
# Epoch: 469, Batch: 2, Avg. Loss: 7.05171786248684e-05
# Epoch: 469, Batch: 4, Avg. Loss: 7.130307704210282e-05
# Epoch: 469, Batch: 6, Avg. Loss: 7.008635997772217e-05
# Epoch: 470, Batch: 2, Avg. Loss: 7.03500583767891e-05
# Epoch: 470, Batch: 4, Avg. Loss: 7.057889550924301e-05
# Epoch: 470, Batch: 6, Avg. Loss: 7.130585238337517e-05
# Epoch: 471, Batch: 2, Avg. Loss: 6.93792887032032e-05
# Epoch: 471, Batch: 4, Avg. Loss: 6.955703347921372e-05
# Epoch: 471, Batch: 6, Avg. Loss: 7.280728220939636e-05
# Epoch: 472, Batch: 2, Avg. Loss: 7.083166763186455e-05
# Epoch: 472, Batch: 4, Avg. Loss: 7.07486905157566e-05
# Epoch: 472, Batch: 6, Avg. Loss: 6.996433809399605e-05
# Epoch: 473, Batch: 2, Avg. Loss: 7.022174447774888e-05
# Epoch: 473, Batch: 4, Avg. Loss: 7.031404227018356e-05
# Epoch: 473, Batch: 6, Avg. Loss: 6.994320452213288e-05
# Epoch: 474, Batch: 2, Avg. Loss: 7.000018656253814e-05
# Epoch: 474, Batch: 4, Avg. Loss: 7.026971131563187e-05
# Epoch: 474, Batch: 6, Avg. Loss: 6.936607137322425e-05
# Epoch: 475, Batch: 2, Avg. Loss: 6.82726390659809e-05
# Epoch: 475, Batch: 4, Avg. Loss: 7.051489874720574e-05
# Epoch: 475, Batch: 6, Avg. Loss: 7.142750546336174e-05
# Epoch: 476, Batch: 2, Avg. Loss: 7.107610255479813e-05
# Epoch: 476, Batch: 4, Avg. Loss: 7.112120464444161e-05
# Epoch: 476, Batch: 6, Avg. Loss: 6.995616480708122e-05
# Epoch: 477, Batch: 2, Avg. Loss: 6.916249543428421e-05
# Epoch: 477, Batch: 4, Avg. Loss: 7.00392834842205e-05
# Epoch: 477, Batch: 6, Avg. Loss: 6.998904794454575e-05
# Epoch: 478, Batch: 2, Avg. Loss: 7.06726536154747e-05
# Epoch: 478, Batch: 4, Avg. Loss: 7.179046049714088e-05
# Epoch: 478, Batch: 6, Avg. Loss: 6.896978989243508e-05
# Epoch: 479, Batch: 2, Avg. Loss: 7.137200608849525e-05
# Epoch: 479, Batch: 4, Avg. Loss: 7.168997824192048e-05
# Epoch: 479, Batch: 6, Avg. Loss: 7.020467147231102e-05
# Epoch: 480, Batch: 2, Avg. Loss: 6.972752884030342e-05
# Epoch: 480, Batch: 4, Avg. Loss: 7.181248068809509e-05
# Epoch: 480, Batch: 6, Avg. Loss: 7.001908123493194e-05
# Epoch: 481, Batch: 2, Avg. Loss: 7.091685011982918e-05
# Epoch: 481, Batch: 4, Avg. Loss: 7.084649801254272e-05
# Epoch: 481, Batch: 6, Avg. Loss: 7.016487047076226e-05
# Epoch: 482, Batch: 2, Avg. Loss: 6.941345706582069e-05
# Epoch: 482, Batch: 4, Avg. Loss: 7.020321488380432e-05
# Epoch: 482, Batch: 6, Avg. Loss: 6.93550705909729e-05
# Epoch: 483, Batch: 2, Avg. Loss: 7.06345997750759e-05
# Epoch: 483, Batch: 4, Avg. Loss: 7.123866304755211e-05
# Epoch: 483, Batch: 6, Avg. Loss: 6.951723247766495e-05
# Epoch: 484, Batch: 2, Avg. Loss: 7.026954740285873e-05
# Epoch: 484, Batch: 4, Avg. Loss: 7.01151117682457e-05
# Epoch: 484, Batch: 6, Avg. Loss: 6.890204176306725e-05
# Epoch: 485, Batch: 2, Avg. Loss: 7.1309145539999e-05
# Epoch: 485, Batch: 4, Avg. Loss: 7.101484760642051e-05
# Epoch: 485, Batch: 6, Avg. Loss: 6.882609426975251e-05
# Epoch: 486, Batch: 2, Avg. Loss: 7.074889540672302e-05
# Epoch: 486, Batch: 4, Avg. Loss: 7.065179571509361e-05
# Epoch: 486, Batch: 6, Avg. Loss: 7.046504318714141e-05
# Epoch: 487, Batch: 2, Avg. Loss: 6.896942481398582e-05
# Epoch: 487, Batch: 4, Avg. Loss: 7.021343708038331e-05
# Epoch: 487, Batch: 6, Avg. Loss: 6.97227120399475e-05
# Epoch: 488, Batch: 2, Avg. Loss: 6.987880542874336e-05
# Epoch: 488, Batch: 4, Avg. Loss: 6.894037872552872e-05
# Epoch: 488, Batch: 6, Avg. Loss: 6.962613016366958e-05
# Epoch: 489, Batch: 2, Avg. Loss: 6.903114914894104e-05
# Epoch: 489, Batch: 4, Avg. Loss: 6.96636438369751e-05
# Epoch: 489, Batch: 6, Avg. Loss: 6.86066783964634e-05
# Epoch: 490, Batch: 2, Avg. Loss: 6.857865676283836e-05
# Epoch: 490, Batch: 4, Avg. Loss: 6.937980279326439e-05
# Epoch: 490, Batch: 6, Avg. Loss: 6.975796818733215e-05
# Epoch: 491, Batch: 2, Avg. Loss: 6.89295195043087e-05
# Epoch: 491, Batch: 4, Avg. Loss: 7.188425958156586e-05
# Epoch: 491, Batch: 6, Avg. Loss: 7.043618708848953e-05
# Epoch: 492, Batch: 2, Avg. Loss: 6.936516612768173e-05
# Epoch: 492, Batch: 4, Avg. Loss: 6.958949565887451e-05
# Epoch: 492, Batch: 6, Avg. Loss: 7.207123935222625e-05
# Epoch: 493, Batch: 2, Avg. Loss: 7.032610848546028e-05
# Epoch: 493, Batch: 4, Avg. Loss: 6.998253613710404e-05
# Epoch: 493, Batch: 6, Avg. Loss: 7.22489133477211e-05
# Epoch: 494, Batch: 2, Avg. Loss: 6.87662959098816e-05
# Epoch: 494, Batch: 4, Avg. Loss: 7.058621570467949e-05
# Epoch: 494, Batch: 6, Avg. Loss: 7.012193277478218e-05
# Epoch: 495, Batch: 2, Avg. Loss: 7.010477036237717e-05
# Epoch: 495, Batch: 4, Avg. Loss: 7.114143297076226e-05
# Epoch: 495, Batch: 6, Avg. Loss: 6.88542015850544e-05
# Epoch: 496, Batch: 2, Avg. Loss: 6.936050578951835e-05
# Epoch: 496, Batch: 4, Avg. Loss: 7.018287852406502e-05
# Epoch: 496, Batch: 6, Avg. Loss: 7.097013294696808e-05
# Epoch: 497, Batch: 2, Avg. Loss: 6.950196623802186e-05
# Epoch: 497, Batch: 4, Avg. Loss: 7.041295617818832e-05
# Epoch: 497, Batch: 6, Avg. Loss: 6.86747133731842e-05
# Epoch: 498, Batch: 2, Avg. Loss: 6.953265145421028e-05
# Epoch: 498, Batch: 4, Avg. Loss: 7.279694825410843e-05
# Epoch: 498, Batch: 6, Avg. Loss: 7.013873383402825e-05
# Epoch: 499, Batch: 2, Avg. Loss: 6.890605762600899e-05
# Epoch: 499, Batch: 4, Avg. Loss: 7.059451565146446e-05
# Epoch: 499, Batch: 6, Avg. Loss: 7.008443400263787e-05
# Epoch: 500, Batch: 2, Avg. Loss: 7.129397988319396e-05
# Epoch: 500, Batch: 4, Avg. Loss: 7.121910899877548e-05
# Epoch: 500, Batch: 6, Avg. Loss: 7.050879299640656e-05
# Finished Training

# %% [markdown]
# ## Test data
#
# See how your model performs on previously unseen, test data. We've already loaded and transformed this data, similar to the training data. Next, run your trained model on these images to see what kind of keypoints are produced. You should be able to see if your model is fitting each new face it sees, if the points are distributed randomly, or if the points have actually overfitted the training data and do not generalize.

# %%
# get a sample of test data again
test_images, test_outputs, gt_pts = net_sample_output()

print(test_images.data.size())
print(test_outputs.data.size())
print(gt_pts.size())
# Out:
# torch.Size([600, 1, 224, 224])
# torch.Size([600, 68, 2])
# torch.Size([600, 68, 2])

# %%
## TODO: visualize your test output
# you can use the same function as before, by un-commenting the line below:

visualize_output(test_images, test_outputs, gt_pts)

# %% [markdown]
# Once you've found a good model (or two), save your model so you can load it and use it later!

# %%
## TODO: change the name to something uniqe for each new model


# after training, save your model parameters in the dir 'saved_models'
torch.save(net.state_dict(), model_dir+model_name)

# %% [markdown]
# After you've trained a well-performing model, answer the following questions so that we have some insight into your training and architecture selection process. Answering all questions is required to pass this project.

# %% [markdown]
# ### Question 1: What optimization and loss functions did you choose and why?

# %% [markdown]
# **Answer**: optimization: Adam, Loss: L1 (abs(x-X_training)). Adam is adaptive optimization which uses exponentially weighted learning rate with decay. This allows adaptive learning rate such that it smoothes over random "jumps" which can overshoot local minimum.

# %% [markdown]
# ### Question 2: What kind of network architecture did you start with and how did it change as you tried different architectures? Did you decide to add more convolutional layers or any layers to avoid overfitting the data?

# %% [markdown]
# **Answer**: I staerted with 5x5 conv1 follewed  3x3 conv layer and 1 fully connected layer and 1 output layer. This architecture didn't work very well as it was able to decrease loss about 50% over 5 or epochs. Eventually I ended up with 4 conv layers : 31, 15, 7, 3 kernel sizes. the assumption was that we need to have a kernel which camputrs each feature of a face, e.g. kernel has to be big anough to caprure shape of the face and small enough to caputure smaller features like eyes. I also added 2 fully connected layers followed by an output layer.

# %% [markdown]
# ### Question 3: How did you decide on the number of epochs and batch_size to train your model?

# %% [markdown]
# ## **Answer**: I did training using DELL XPS laptop with Nvidia 1650 GPU with 4 GB of memory. I set batch size to utilize about 3 GB out of 4GB available in the GPU. My total epoch number was 24. I ddn't see much improvement in the last 1 epochs, so I stopped. Note that in the notebook only the last 1 epoch are showed. I run that cell multiple times such that output from first 23 epochs is not shown. The original error was around 0.0055. The error after 13 epochs is 0.00100

# %% [markdown]
# ## Feature Visualization
#
# Sometimes, neural networks are thought of as a black box, given some input, they learn to produce some output. CNN's are actually learning to recognize a variety of spatial patterns and you can visualize what each convolutional layer has been trained to recognize by looking at the weights that make up each convolutional kernel and applying those one at a time to a sample image. This technique is called feature visualization and it's useful for understanding the inner workings of a CNN.

# %% [markdown]
# In the cell below, you can see how to extract a single filter (by index) from your first convolutional layer. The filter should appear as a grayscale grid.

# %%
# Get the weights in the first conv layer, "conv1"
# if necessary, change this to reflect the name of your first conv layer
weights1 = net.conv1.weight.data

w = weights1.cpu().numpy()

filter_index = 0

#print(w[filter_index][0])
print(w[filter_index][0].shape)

# display the filter weights
plt.imshow(w[filter_index][0], cmap='gray')
# Out:
# (31, 31)

# %% [markdown]
# ## Feature maps
#
# Each CNN has at least one convolutional layer that is composed of stacked filters (also known as convolutional kernels). As a CNN trains, it learns what weights to include in it's convolutional kernels and when these kernels are applied to some input image, they produce a set of **feature maps**. So, feature maps are just sets of filtered images; they are the images produced by applying a convolutional kernel to an input image. These maps show us the features that the different layers of the neural network learn to extract. For example, you might imagine a convolutional kernel that detects the vertical edges of a face or another one that detects the corners of eyes. You can see what kind of features each of these kernels detects by applying them to an image. One such example is shown below; from the way it brings out the lines in an the image, you might characterize this as an edge detection filter.
#
# <img src='images/feature_map_ex.png' width=50% height=50%/>
#
#
# Next, choose a test image and filter it with one of the convolutional kernels in your trained CNN; look at the filtered output to get an idea what that particular kernel detects.
#
# ### TODO: Filter an image to see the effect of a convolutional kernel
# ---

# %%
##TODO: load in and display any image from the transformed test dataset

## TODO: Using cv's filter2D function,
## apply a specific set of filter weights (like the one displayed above) to the test image
import cv2
weights1 = net.conv1.weight.data
w = weights1.cpu().numpy()
image = test_images[i].data.cpu()   # get the image from it's wrapper
image = image.numpy()   # convert to numpy array from a Tensor
image = np.transpose(image, (1, 2, 0))[:,:,0]   # transpose to go from torch to numpy image
print(image.shape)
filtered = cv2.filter2D(image, -1, w[filter_index][0])
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(221, xticks = [], yticks = [])
ax.imshow(image, cmap="gray")
ax.set_title("Image")
ax = fig.add_subplot(222, xticks = [], yticks = [])
print(filtered.shape)
ax.imshow(filtered)
ax.set_title("Filtered Image")
# Out:
# (224, 224)
# (224, 224)
# Text(0.5,1,'Filtered Image')

# %% [markdown]
# ### Question 4: Choose one filter from your trained CNN and apply it to a test image; what purpose do you think it plays? What kind of feature do you think it detects?

# %% [markdown]
# **Answer**: Looks like a high pass filter, it removes all subtle edges and keeps prominets edges only, like shape of a face, nose, eyes and a hat.

# %% [markdown]
# ---
# ## Moving on!
#
# Now that you've defined and trained your model (and saved the best model), you are ready to move on to the last notebook, which combines a face detector with your saved model to create a facial keypoint detection system that can predict the keypoints on *any* face in an image!
